# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("coches_segunda_mano-17-02-2025.csv")

# %%
df
# Out:
#                                                 marca     anio localizacion  \
# 0           PEUGEOT 308 SW 1.5 BlueHDi S&S Allure 130  01/2021      Sevilla
# 1                     VOLVO XC60 B4 R-Design AWD Aut.  01/2021      Sevilla
# 2   PEUGEOT Rifter 1.5BlueHDi S&S Long Active Pack...  09/2020      Almería
# 3   KIA Sportage Todoterreno 136cv Automático de 4...  10/2023     Valencia
# 4                                      AUDI Q8 s-line  08/2023     Valencia
# ..                                                ...      ...          ...
# 75                 SEAT Tarraco 1.5 TSI S&S Style 150  09/2019      Almería
# 76                     RENAULT Captur TCe Techno 67kW  03/2024       Madrid
# 77                    CUPRA Formentor 1.5 TSI 150 DSG  06/2024      Almería
# 78               FORD Puma 1.0 EcoBoost ST-Line X 125  02/2020     Albacete
# 79        PEUGEOT 408 1.6 PHEV 133KW GT E-AUTO 181 5P  06/2023       Toledo
#
#    kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0   156.000 km      Diesel                    C  12 meses      Manual
# 1    95.000 km      Diesel                  ECO  12 meses  Automático
# 2   115.000 km      Diesel                    C  12 meses      Manual
# 3    21.470 km         NaN                  NaN  12 meses  Automático
# 4    17.290 km      Diésel                  NaN  12 meses  Automático
# ..         ...         ...                  ...       ...         ...
# 75   71.800 km    Gasolina                    C  24 meses      Manual
# 76   18.426 km    Gasolina                    C  12 meses      Manual
# 77    3.000 km    Gasolina                    C  36 meses  Automático
# 78   35.700 km    Gasolina                    C  12 meses      Manual
# 79       50 km   Eléctrico          0 EMISIONES  24 meses  Automático
#
#                   carroceria      plazas potencia    puertas  \
# 0               Stationwagon  5 asientos   130 cv  5 Puertas
# 1               Todo Terreno  5 asientos   197 cv  5 Puertas
# 2                Monovolumen  5 asientos   131 cv  5 Puertas
# 3          4x4, SUV o pickup         NaN   136 cv  4 Puertas
# 4          4x4, SUV o pickup         NaN   286 cv  4 Puertas
# ..                       ...         ...      ...        ...
# 75              Todo Terreno  5 asientos   150 cv  5 Puertas
# 76              Todo Terreno  5 asientos    90 cv  5 Puertas
# 77              Todo Terreno  5 asientos   150 cv  5 Puertas
# 78              Todo Terreno  5 asientos   125 cv  5 Puertas
# 79  Berlina mediana o grande         NaN   181 cv  5 Puertas
#
#                   color                  precio  \
# 0   Blanco / Metalizado                11.990 €
# 1     Azul / Metalizado                39.990 €
# 2                 Negro                18.500 €
# 3                 PLATA                31.460 €
# 4                BLANCO                72.274 €
# ..                  ...                     ...
# 75                 Gris                23.900 €
# 76    Gris / Metalizado  21.290 €\n6%\n19.990 €
# 77               Blanco                29.000 €
# 78                 Rojo                19.900 €
# 79        GRIS PLATINUM                38.300 €
#
#                                              vendedor  \
# 0                     MOTOR CLUB SEVILLA\nProfesional
# 1                     MOTOR CLUB SEVILLA\nProfesional
# 2                            AUTOMERCURY\nProfesional
# 3                     LEASING AUTOMOBILE\nProfesional
# 4                     LEASING AUTOMOBILE\nProfesional
# ..                                                ...
# 75  INDALO MOTOR Concesionario Oficial SEAT\nProfe...
# 76                        CLICARS MADRID\nProfesional
# 77  INDALO MOTOR Concesionario Oficial SEAT\nProfe...
# 78                   AUTOMOVILES GARRIDO\nProfesional
# 79                         BONILLA MOTOR\nProfesional
#
#                          consumo_medio certificado  \
# 0   Consumo medio\n0,00\nlitros/100 km          No
# 1   Consumo medio\n5,50\nlitros/100 km          No
# 2   Consumo medio\n4,30\nlitros/100 km          No
# 3                                  NaN          No
# 4                                  NaN          No
# ..                                 ...         ...
# 75  Consumo medio\n5,80\nlitros/100 km          No
# 76  Consumo medio\n0,00\nlitros/100 km          No
# 77  Consumo medio\n5,50\nlitros/100 km          No
# 78  Consumo medio\n4,50\nlitros/100 km          No
# 79                                 NaN          No
#
#               fecha_extraccion   referencia
# 0   2025-02-17 19:26:27.595606  ref15276957
# 1   2025-02-17 19:26:35.003246  ref15168174
# 2   2025-02-17 19:26:44.036638  ref13903932
# 3   2025-02-17 19:26:52.390413  ref15317252
# 4   2025-02-17 19:27:07.527248  ref15218308
# ..                         ...          ...
# 75  2025-02-17 19:37:41.617133  ref15066087
# 76  2025-02-17 19:37:49.595653  ref15390517
# 77  2025-02-17 19:37:59.121730  ref15063293
# 78  2025-02-17 19:38:08.024708  ref15440616
# 79  2025-02-17 19:38:16.024757  ref15238745
#
# [80 rows x 19 columns]

# %%
df["consumo_medio"].value_counts()
# Out:
# consumo_medio
# Consumo medio\n0,00\nlitros/100 km    29
# Consumo medio\nlitros/100 km           4
# Consumo medio\n5,50\nlitros/100 km     3
# Consumo medio\n4,90\nlitros/100 km     3
# Consumo medio\n5,80\nlitros/100 km     3
# Consumo medio\n4,60\nlitros/100 km     2
# Consumo medio\n5,40\nlitros/100 km     2
# Consumo medio\n4,30\nlitros/100 km     2
# Consumo medio\n4,80\nlitros/100 km     2
# Consumo medio\n6,10\nlitros/100 km     1
# Consumo medio\n4,00\nlitros/100 km     1
# Consumo medio\n3,70\nlitros/100 km     1
# Consumo medio\n4,20\nlitros/100 km     1
# Consumo medio\n4,70\nlitros/100 km     1
# Consumo medio\n7,00\nlitros/100 km     1
# Consumo medio\n5,00\nlitros/100 km     1
# Consumo medio\n3,20\nlitros/100 km     1
# Consumo medio\n3,80\nlitros/100 km     1
# Consumo medio\n1,40\nlitros/100 km     1
# Consumo medio\n5,70\nlitros/100 km     1
# Consumo medio\n4,50\nlitros/100 km     1
# Name: count, dtype: int64

# %%
df["consumo_medio"].isna().sum()
# Out:
# np.int64(18)

# %%
# campo nuevo marca_sola

df['marca_sola'] = df['marca'].apply(lambda x: x.split()[0] if isinstance(x, str) else x)

# %%
# renombrar "marca" por "modelo_titulo" y quitar marca

df.rename(columns={'marca': 'modelo_titulo'}, inplace=True)
df['modelo_titulo'] = df['modelo_titulo'].apply(lambda x: ' '.join(x.split()[1:]) if isinstance(x, str) else x)

# %%
df
# Out:
#                                         modelo_titulo     anio localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130  01/2021      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.  01/2021      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130  09/2020      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...  10/2023     Valencia
# 4                                           Q8 s-line  08/2023     Valencia
# ..                                                ...      ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150  09/2019      Almería
# 76                             Captur TCe Techno 67kW  03/2024       Madrid
# 77                          Formentor 1.5 TSI 150 DSG  06/2024      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125  02/2020     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P  06/2023       Toledo
#
#    kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0   156.000 km      Diesel                    C  12 meses      Manual
# 1    95.000 km      Diesel                  ECO  12 meses  Automático
# 2   115.000 km      Diesel                    C  12 meses      Manual
# 3    21.470 km         NaN                  NaN  12 meses  Automático
# 4    17.290 km      Diésel                  NaN  12 meses  Automático
# ..         ...         ...                  ...       ...         ...
# 75   71.800 km    Gasolina                    C  24 meses      Manual
# 76   18.426 km    Gasolina                    C  12 meses      Manual
# 77    3.000 km    Gasolina                    C  36 meses  Automático
# 78   35.700 km    Gasolina                    C  12 meses      Manual
# 79       50 km   Eléctrico          0 EMISIONES  24 meses  Automático
#
#                   carroceria      plazas potencia    puertas  \
# 0               Stationwagon  5 asientos   130 cv  5 Puertas
# 1               Todo Terreno  5 asientos   197 cv  5 Puertas
# 2                Monovolumen  5 asientos   131 cv  5 Puertas
# 3          4x4, SUV o pickup         NaN   136 cv  4 Puertas
# 4          4x4, SUV o pickup         NaN   286 cv  4 Puertas
# ..                       ...         ...      ...        ...
# 75              Todo Terreno  5 asientos   150 cv  5 Puertas
# 76              Todo Terreno  5 asientos    90 cv  5 Puertas
# 77              Todo Terreno  5 asientos   150 cv  5 Puertas
# 78              Todo Terreno  5 asientos   125 cv  5 Puertas
# 79  Berlina mediana o grande         NaN   181 cv  5 Puertas
#
#                   color                  precio  \
# 0   Blanco / Metalizado                11.990 €
# 1     Azul / Metalizado                39.990 €
# 2                 Negro                18.500 €
# 3                 PLATA                31.460 €
# 4                BLANCO                72.274 €
# ..                  ...                     ...
# 75                 Gris                23.900 €
# 76    Gris / Metalizado  21.290 €\n6%\n19.990 €
# 77               Blanco                29.000 €
# 78                 Rojo                19.900 €
# 79        GRIS PLATINUM                38.300 €
#
#                                              vendedor  \
# 0                     MOTOR CLUB SEVILLA\nProfesional
# 1                     MOTOR CLUB SEVILLA\nProfesional
# 2                            AUTOMERCURY\nProfesional
# 3                     LEASING AUTOMOBILE\nProfesional
# 4                     LEASING AUTOMOBILE\nProfesional
# ..                                                ...
# 75  INDALO MOTOR Concesionario Oficial SEAT\nProfe...
# 76                        CLICARS MADRID\nProfesional
# 77  INDALO MOTOR Concesionario Oficial SEAT\nProfe...
# 78                   AUTOMOVILES GARRIDO\nProfesional
# 79                         BONILLA MOTOR\nProfesional
#
#                          consumo_medio certificado  \
# 0   Consumo medio\n0,00\nlitros/100 km          No
# 1   Consumo medio\n5,50\nlitros/100 km          No
# 2   Consumo medio\n4,30\nlitros/100 km          No
# 3                                  NaN          No
# 4                                  NaN          No
# ..                                 ...         ...
# 75  Consumo medio\n5,80\nlitros/100 km          No
# 76  Consumo medio\n0,00\nlitros/100 km          No
# 77  Consumo medio\n5,50\nlitros/100 km          No
# 78  Consumo medio\n4,50\nlitros/100 km          No
# 79                                 NaN          No
#
#               fecha_extraccion   referencia marca_sola
# 0   2025-02-17 19:26:27.595606  ref15276957    PEUGEOT
# 1   2025-02-17 19:26:35.003246  ref15168174      VOLVO
# 2   2025-02-17 19:26:44.036638  ref13903932    PEUGEOT
# 3   2025-02-17 19:26:52.390413  ref15317252        KIA
# 4   2025-02-17 19:27:07.527248  ref15218308       AUDI
# ..                         ...          ...        ...
# 75  2025-02-17 19:37:41.617133  ref15066087       SEAT
# 76  2025-02-17 19:37:49.595653  ref15390517    RENAULT
# 77  2025-02-17 19:37:59.121730  ref15063293      CUPRA
# 78  2025-02-17 19:38:08.024708  ref15440616       FORD
# 79  2025-02-17 19:38:16.024757  ref15238745    PEUGEOT
#
# [80 rows x 20 columns]

# %%
# sacar mes y año en columnas separadas

df[['mes_matricula', 'anio_matricula']] = df['anio'].str.split('/', expand=True)

df['mes_matricula'] = df['mes_matricula'].astype(int)
df['anio_matricula'] = df['anio_matricula'].astype(int)

df.drop(columns=["anio"], inplace=True)

# %%
def limpiar_kilometraje(valor):
    valor_limpio = valor.replace(".","").replace(" km","")
    return int(valor_limpio)

# %%
df["kilometraje"] = df["kilometraje"].apply(lambda x: limpiar_kilometraje(x) if isinstance(x, str) else np.nan)

# %%
df["garantia"].unique()
# Out:
# array(['12 meses', 'No', '18 meses', '24 meses', '60 meses', '36 meses'],
#       dtype=object)

# %%
df[df["garantia"] == " meses"]["vendedor"].unique()
# Out:
# array([], dtype=object)

# %%
df["garantia"] = df["garantia"].replace("No", 0)
df["garantia"] = df["garantia"].replace("Sí", np.nan)
df["garantia"] = pd.to_numeric(df["garantia"].str.replace(" meses", ""), errors='coerce')

# %%
df.head(10)
# Out:
#                                        modelo_titulo localizacion  \
# 0                  308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                          XC60 B4 R-Design AWD Aut.      Sevilla
# 2         Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3  Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                          Q8 s-line     Valencia
# 5                                Serie 7 740 m-sport     Valencia
# 6                      500 1.0 Hybrid Dolcevita 52kW       Málaga
# 7       X3 Todoterreno 190cv Automático de 4 Puertas     Valencia
# 8                              Serie 5 520dA M Sport     Valencia
# 9           Berlingo M1 BlueHDi S&S Talla M Feel 100      Almería
#
#    kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0       156000      Diesel                    C      12.0      Manual
# 1        95000      Diesel                  ECO      12.0  Automático
# 2       115000      Diesel                    C      12.0      Manual
# 3        21470         NaN                  NaN      12.0  Automático
# 4        17290      Diésel                  NaN      12.0  Automático
# 5        42573      Diésel                  NaN      12.0  Automático
# 6        52446    Gasolina                  ECO      12.0      Manual
# 7       112899      Diésel                  NaN      12.0  Automático
# 8        65750      Diesel                  ECO      12.0  Automático
# 9        97600      Diesel                    C      12.0      Manual
#
#           carroceria      plazas potencia  ...                color    precio  \
# 0       Stationwagon  5 asientos   130 cv  ...  Blanco / Metalizado  11.990 €
# 1       Todo Terreno  5 asientos   197 cv  ...    Azul / Metalizado  39.990 €
# 2        Monovolumen  5 asientos   131 cv  ...                Negro  18.500 €
# 3  4x4, SUV o pickup         NaN   136 cv  ...                PLATA  31.460 €
# 4  4x4, SUV o pickup         NaN   286 cv  ...               BLANCO  72.274 €
# 5  4x4, SUV o pickup         NaN   340 cv  ...                NEGRO  72.040 €
# 6            Berlina  4 asientos    70 cv  ...  Blanco / Metalizado  11.900 €
# 7  4x4, SUV o pickup         NaN   190 cv  ...               BLANCO  28.887 €
# 8            Berlina  5 asientos   197 cv  ...                NEGRO  35.674 €
# 9        Monovolumen  5 asientos   100 cv  ...                Negro  17.900 €
#
#                              vendedor                       consumo_medio  \
# 0     MOTOR CLUB SEVILLA\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 1     MOTOR CLUB SEVILLA\nProfesional  Consumo medio\n5,50\nlitros/100 km
# 2            AUTOMERCURY\nProfesional  Consumo medio\n4,30\nlitros/100 km
# 3     LEASING AUTOMOBILE\nProfesional                                 NaN
# 4     LEASING AUTOMOBILE\nProfesional                                 NaN
# 5     LEASING AUTOMOBILE\nProfesional                                 NaN
# 6  LAS CLARAS AUTOMOCION\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 7     LEASING AUTOMOBILE\nProfesional                                 NaN
# 8     LEASING AUTOMOBILE\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 9            AUTOMERCURY\nProfesional  Consumo medio\n4,00\nlitros/100 km
#
#   certificado            fecha_extraccion   referencia marca_sola  \
# 0          No  2025-02-17 19:26:27.595606  ref15276957    PEUGEOT
# 1          No  2025-02-17 19:26:35.003246  ref15168174      VOLVO
# 2          No  2025-02-17 19:26:44.036638  ref13903932    PEUGEOT
# 3          No  2025-02-17 19:26:52.390413  ref15317252        KIA
# 4          No  2025-02-17 19:27:07.527248  ref15218308       AUDI
# 5          No  2025-02-17 19:27:16.169545  ref15218306        BMW
# 6          No  2025-02-17 19:27:25.459010  ref15403473       FIAT
# 7          No  2025-02-17 19:27:34.651727  ref15218305        BMW
# 8          No  2025-02-17 19:27:41.299602  ref15218300        BMW
# 9          No  2025-02-17 19:27:49.677432  ref12163959    CITROEN
#
#   mes_matricula  anio_matricula
# 0             1            2021
# 1             1            2021
# 2             9            2020
# 3            10            2023
# 4             8            2023
# 5             1            2022
# 6             5            2022
# 7            10            2019
# 8            12            2020
# 9             6            2019
#
# [10 rows x 21 columns]

# %%
media_garantia = pd.to_numeric(round(df["garantia"].mean(), 0))
df['garantia'] = df["garantia"].fillna(media_garantia)

# %%
df["consumo_medio"].unique()
# Out:
# array(['Consumo medio\n0,00\nlitros/100 km',
#        'Consumo medio\n5,50\nlitros/100 km',
#        'Consumo medio\n4,30\nlitros/100 km', nan,
#        'Consumo medio\n4,00\nlitros/100 km',
#        'Consumo medio\n6,10\nlitros/100 km',
#        'Consumo medio\n4,80\nlitros/100 km',
#        'Consumo medio\n4,20\nlitros/100 km',
#        'Consumo medio\n5,00\nlitros/100 km',
#        'Consumo medio\n3,70\nlitros/100 km',
#        'Consumo medio\n4,90\nlitros/100 km',
#        'Consumo medio\n7,00\nlitros/100 km',
#        'Consumo medio\n4,70\nlitros/100 km',
#        'Consumo medio\n4,60\nlitros/100 km',
#        'Consumo medio\n3,20\nlitros/100 km',
#        'Consumo medio\n1,40\nlitros/100 km',
#        'Consumo medio\n3,80\nlitros/100 km',
#        'Consumo medio\nlitros/100 km',
#        'Consumo medio\n5,80\nlitros/100 km',
#        'Consumo medio\n5,70\nlitros/100 km',
#        'Consumo medio\n5,40\nlitros/100 km',
#        'Consumo medio\n4,50\nlitros/100 km'], dtype=object)

# %%
# convertir a nan los que contengan \nlitros
# sustituir valor por solo lo que hay entre medio\n y \nlitros convertido a float redondeado a 2
# sustituir nans por media (22,5% en muestra: hay que ver porcentaje total de nans y hablar con grupo)


#df['consumo_medio'] = df['consumo_medio'].replace(r'.*\\nlitros.*', np.nan, regex=True)

# Paso 2: Sustituir el valor por solo lo que hay entre "medio\n" y "\nlitros" convertido a float redondeado a 2 decimales
#df['consumo_medio'] = df['consumo_medio'].apply(lambda x: float(re.search(r'medio\n(.*?)\nlitros', x).group(1)) if isinstance(x, str) and re.search(r'medio\n(.*?)\nlitros', x) else x)

# Paso 3: Sustituir NaNs por la media de la columna
#mean_value = df['consumo_medio'].mean()
# df['consumo_medio'] = df['consumo_medio'].fillna(mean_value)

# %%
df
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#                   carroceria      plazas potencia  ...                color  \
# 0               Stationwagon  5 asientos   130 cv  ...  Blanco / Metalizado
# 1               Todo Terreno  5 asientos   197 cv  ...    Azul / Metalizado
# 2                Monovolumen  5 asientos   131 cv  ...                Negro
# 3          4x4, SUV o pickup         NaN   136 cv  ...                PLATA
# 4          4x4, SUV o pickup         NaN   286 cv  ...               BLANCO
# ..                       ...         ...      ...  ...                  ...
# 75              Todo Terreno  5 asientos   150 cv  ...                 Gris
# 76              Todo Terreno  5 asientos    90 cv  ...    Gris / Metalizado
# 77              Todo Terreno  5 asientos   150 cv  ...               Blanco
# 78              Todo Terreno  5 asientos   125 cv  ...                 Rojo
# 79  Berlina mediana o grande         NaN   181 cv  ...        GRIS PLATINUM
#
#                     precio                                           vendedor  \
# 0                 11.990 €                    MOTOR CLUB SEVILLA\nProfesional
# 1                 39.990 €                    MOTOR CLUB SEVILLA\nProfesional
# 2                 18.500 €                           AUTOMERCURY\nProfesional
# 3                 31.460 €                    LEASING AUTOMOBILE\nProfesional
# 4                 72.274 €                    LEASING AUTOMOBILE\nProfesional
# ..                     ...                                                ...
# 75                23.900 €  INDALO MOTOR Concesionario Oficial SEAT\nProfe...
# 76  21.290 €\n6%\n19.990 €                        CLICARS MADRID\nProfesional
# 77                29.000 €  INDALO MOTOR Concesionario Oficial SEAT\nProfe...
# 78                19.900 €                   AUTOMOVILES GARRIDO\nProfesional
# 79                38.300 €                         BONILLA MOTOR\nProfesional
#
#                          consumo_medio certificado  \
# 0   Consumo medio\n0,00\nlitros/100 km          No
# 1   Consumo medio\n5,50\nlitros/100 km          No
# 2   Consumo medio\n4,30\nlitros/100 km          No
# 3                             4.831034          No
# 4                             4.831034          No
# ..                                 ...         ...
# 75  Consumo medio\n5,80\nlitros/100 km          No
# 76  Consumo medio\n0,00\nlitros/100 km          No
# 77  Consumo medio\n5,50\nlitros/100 km          No
# 78  Consumo medio\n4,50\nlitros/100 km          No
# 79                            4.831034          No
#
#               fecha_extraccion   referencia marca_sola mes_matricula  \
# 0   2025-02-17 19:26:27.595606  ref15276957    PEUGEOT             1
# 1   2025-02-17 19:26:35.003246  ref15168174      VOLVO             1
# 2   2025-02-17 19:26:44.036638  ref13903932    PEUGEOT             9
# 3   2025-02-17 19:26:52.390413  ref15317252        KIA            10
# 4   2025-02-17 19:27:07.527248  ref15218308       AUDI             8
# ..                         ...          ...        ...           ...
# 75  2025-02-17 19:37:41.617133  ref15066087       SEAT             9
# 76  2025-02-17 19:37:49.595653  ref15390517    RENAULT             3
# 77  2025-02-17 19:37:59.121730  ref15063293      CUPRA             6
# 78  2025-02-17 19:38:08.024708  ref15440616       FORD             2
# 79  2025-02-17 19:38:16.024757  ref15238745    PEUGEOT             6
#
#     anio_matricula
# 0             2021
# 1             2021
# 2             2020
# 3             2023
# 4             2023
# ..             ...
# 75            2019
# 76            2024
# 77            2024
# 78            2020
# 79            2023
#
# [80 rows x 21 columns]

# %%
df['referencia'] = pd.to_numeric(df['referencia'].str.replace('ref', ''), errors='coerce')

# %%
df["nombre_vendedor_profesional"] = pd.Series(dtype="string")
mask = df['vendedor'].str.endswith('\nProfesional')
df.loc[mask, 'nombre_vendedor_profesional'] = df.loc[mask, 'vendedor'].str.split('\nProfesional').str[0]
df['vendedor'] = df['vendedor'].apply(lambda x: True if '\nProfesional' in x else False)
df.rename(columns={'vendedor':'vendedor_profesional'}, inplace=True)
df['vendedor_profesional'].astype(bool)

# %%
df['color']=df['color'].apply(lambda x: x.upper())

# %%
# Traducir al español los colores en inglés y alemán
# "plateado" va al saco de grises

df.loc[df["color"].str.contains("BLACK|SCHWARZ", regex=True), "color"] = "NEGRO"
df.loc[df["color"].str.contains("WHITE|WEISS", regex=True), "color"] = "BLANCO"
df.loc[df["color"].str.contains("RED|ROT", regex=True), "color"] = "ROJO"
df.loc[df["color"].str.contains("BLUE|BLAU", regex=True), "color"] = "AZUL"
df.loc[df["color"].str.contains("GRAY|GREY|GRAU|PLATEADO|SILVER", regex=True), "color"] = "GRIS"

# %%
df['color'] = df['color'].str.split().str[0]

# %%
colores = ["NEGRO", "BLANCO", "AZUL", "ROJO", "GRIS"]
df['color'] = df['color'].apply(lambda x: x if x in colores else 'OTROS')

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#                   carroceria      plazas potencia    puertas   color  \
# 0               Stationwagon  5 asientos   130 cv  5 Puertas  BLANCO
# 1               Todo Terreno  5 asientos   197 cv  5 Puertas    AZUL
# 2                Monovolumen  5 asientos   131 cv  5 Puertas   NEGRO
# 3          4x4, SUV o pickup         NaN   136 cv  4 Puertas   OTROS
# 4          4x4, SUV o pickup         NaN   286 cv  4 Puertas  BLANCO
# ..                       ...         ...      ...        ...     ...
# 75              Todo Terreno  5 asientos   150 cv  5 Puertas    GRIS
# 76              Todo Terreno  5 asientos    90 cv  5 Puertas    GRIS
# 77              Todo Terreno  5 asientos   150 cv  5 Puertas  BLANCO
# 78              Todo Terreno  5 asientos   125 cv  5 Puertas    ROJO
# 79  Berlina mediana o grande         NaN   181 cv  5 Puertas    GRIS
#
#                     precio     vendedor                       consumo_medio  \
# 0                 11.990 €  Profesional  Consumo medio\n0,00\nlitros/100 km
# 1                 39.990 €  Profesional  Consumo medio\n5,50\nlitros/100 km
# 2                 18.500 €  Profesional  Consumo medio\n4,30\nlitros/100 km
# 3                 31.460 €  Profesional                            4.831034
# 4                 72.274 €  Profesional                            4.831034
# ..                     ...          ...                                 ...
# 75                23.900 €  Profesional  Consumo medio\n5,80\nlitros/100 km
# 76  21.290 €\n6%\n19.990 €  Profesional  Consumo medio\n0,00\nlitros/100 km
# 77                29.000 €  Profesional  Consumo medio\n5,50\nlitros/100 km
# 78                19.900 €  Profesional  Consumo medio\n4,50\nlitros/100 km
# 79                38.300 €  Profesional                            4.831034
#
#    certificado            fecha_extraccion  referencia marca_sola
# 0           No  2025-02-17 19:26:27.595606    15276957    PEUGEOT
# 1           No  2025-02-17 19:26:35.003246    15168174      VOLVO
# 2           No  2025-02-17 19:26:44.036638    13903932    PEUGEOT
# 3           No  2025-02-17 19:26:52.390413    15317252        KIA
# 4           No  2025-02-17 19:27:07.527248    15218308       AUDI
# ..         ...                         ...         ...        ...
# 75          No  2025-02-17 19:37:41.617133    15066087       SEAT
# 76          No  2025-02-17 19:37:49.595653    15390517    RENAULT
# 77          No  2025-02-17 19:37:59.121730    15063293      CUPRA
# 78          No  2025-02-17 19:38:08.024708    15440616       FORD
# 79          No  2025-02-17 19:38:16.024757    15238745    PEUGEOT
#
# [80 rows x 19 columns]

# %%
df["carroceria"].unique()
# Out:
# array(['Stationwagon', 'Todo Terreno', 'Monovolumen', '4x4, SUV o pickup',
#        'Berlina', 'Coupe', 'Pequeño', 'Berlina mediana o grande',
#        'Familiar'], dtype=object)

# %%
df['carroceria'].value_counts()
# Out:
# carroceria
# Todo Terreno                30
# Berlina                     24
# 4x4, SUV o pickup           10
# Berlina mediana o grande     5
# Stationwagon                 3
# Monovolumen                  3
# Coupe                        3
# Pequeño                      1
# Familiar                     1
# Name: count, dtype: int64

# %%
df["carroceria"] = df["carroceria"].replace("Berlina mediana o grande", "Berlina")

# %%
df['carroceria'].value_counts()
# Out:
# carroceria
# Todo Terreno         30
# Berlina              29
# 4x4, SUV o pickup    10
# Stationwagon          3
# Monovolumen           3
# Coupe                 3
# Pequeño               1
# Familiar              1
# Name: count, dtype: int64

# %%
df["carroceria"] = df["carroceria"].replace("Stationwagon", "Familiar")

# %%
df['carroceria'].value_counts()
# Out:
# carroceria
# Todo Terreno         30
# Berlina              29
# 4x4, SUV o pickup    10
# Familiar              4
# Monovolumen           3
# Coupe                 3
# Pequeño               1
# Name: count, dtype: int64

# %%
df["plazas"] = pd.to_numeric(df["plazas"].str.replace(" asientos", ""), errors='coerce')

# %%
df.head(3)
# Out:
#                                 modelo_titulo localizacion  kilometraje  \
# 0           308 SW 1.5 BlueHDi S&S Allure 130      Sevilla       156000
# 1                   XC60 B4 R-Design AWD Aut.      Sevilla        95000
# 2  Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería       115000
#
#   combustible distintivo_ambiental  garantia      cambio    carroceria  \
# 0      Diesel                    C      12.0      Manual      Familiar
# 1      Diesel                  ECO      12.0  Automático  Todo Terreno
# 2      Diesel                    C      12.0      Manual   Monovolumen
#
#    plazas potencia  ...    precio     vendedor  \
# 0     5.0   130 cv  ...  11.990 €  Profesional
# 1     5.0   197 cv  ...  39.990 €  Profesional
# 2     5.0   131 cv  ...  18.500 €  Profesional
#
#                         consumo_medio certificado            fecha_extraccion  \
# 0  Consumo medio\n0,00\nlitros/100 km          No  2025-02-17 19:26:27.595606
# 1  Consumo medio\n5,50\nlitros/100 km          No  2025-02-17 19:26:35.003246
# 2  Consumo medio\n4,30\nlitros/100 km          No  2025-02-17 19:26:44.036638
#
#   referencia marca_sola  mes_matricula anio_matricula  vendedor_profesional
# 0   15276957    PEUGEOT              1           2021    MOTOR CLUB SEVILLA
# 1   15168174      VOLVO              1           2021    MOTOR CLUB SEVILLA
# 2   13903932    PEUGEOT              9           2020           AUTOMERCURY
#
# [3 rows x 22 columns]

# %%
df["puertas"] = pd.to_numeric(df["puertas"].str.replace(" Puertas", ""), errors='coerce')

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#            carroceria  plazas potencia  puertas   color  \
# 0            Familiar     5.0   130 cv        5  BLANCO
# 1        Todo Terreno     5.0   197 cv        5    AZUL
# 2         Monovolumen     5.0   131 cv        5   NEGRO
# 3   4x4, SUV o pickup     NaN   136 cv        4   OTROS
# 4   4x4, SUV o pickup     NaN   286 cv        4  BLANCO
# ..                ...     ...      ...      ...     ...
# 75       Todo Terreno     5.0   150 cv        5    GRIS
# 76       Todo Terreno     5.0    90 cv        5    GRIS
# 77       Todo Terreno     5.0   150 cv        5  BLANCO
# 78       Todo Terreno     5.0   125 cv        5    ROJO
# 79            Berlina     NaN   181 cv        5    GRIS
#
#                     precio     vendedor                       consumo_medio  \
# 0                 11.990 €  Profesional  Consumo medio\n0,00\nlitros/100 km
# 1                 39.990 €  Profesional  Consumo medio\n5,50\nlitros/100 km
# 2                 18.500 €  Profesional  Consumo medio\n4,30\nlitros/100 km
# 3                 31.460 €  Profesional                            4.831034
# 4                 72.274 €  Profesional                            4.831034
# ..                     ...          ...                                 ...
# 75                23.900 €  Profesional  Consumo medio\n5,80\nlitros/100 km
# 76  21.290 €\n6%\n19.990 €  Profesional  Consumo medio\n0,00\nlitros/100 km
# 77                29.000 €  Profesional  Consumo medio\n5,50\nlitros/100 km
# 78                19.900 €  Profesional  Consumo medio\n4,50\nlitros/100 km
# 79                38.300 €  Profesional                            4.831034
#
#    certificado            fecha_extraccion  referencia marca_sola
# 0           No  2025-02-17 19:26:27.595606    15276957    PEUGEOT
# 1           No  2025-02-17 19:26:35.003246    15168174      VOLVO
# 2           No  2025-02-17 19:26:44.036638    13903932    PEUGEOT
# 3           No  2025-02-17 19:26:52.390413    15317252        KIA
# 4           No  2025-02-17 19:27:07.527248    15218308       AUDI
# ..         ...                         ...         ...        ...
# 75          No  2025-02-17 19:37:41.617133    15066087       SEAT
# 76          No  2025-02-17 19:37:49.595653    15390517    RENAULT
# 77          No  2025-02-17 19:37:59.121730    15063293      CUPRA
# 78          No  2025-02-17 19:38:08.024708    15440616       FORD
# 79          No  2025-02-17 19:38:16.024757    15238745    PEUGEOT
#
# [80 rows x 19 columns]

# %%
# Paso 1: Sustituir por NaN los valores que contengan "medio\n0,00\nlitros" o "medio\nlitros"
df['consumo_medio'] = df['consumo_medio'].replace(
    [r'.*medio\n0,00\nlitros.*', r'.*medio\nlitros.*'], np.nan, regex=True)

# Paso 2: Dejar solo el número entre "medio\n" y "\nlitros" y convertir a float redondeado a 2 decimales
df['consumo_medio'] = df['consumo_medio'].str.extract(r'medio\n(.*?)\nlitros')[0]
df['consumo_medio'] = df['consumo_medio'].str.replace(',', '.').astype(float).round(2)

# mean_value = df['consumo_medio'].mean().round(2)
# df['consumo_medio'].fillna(mean_value, inplace=True)

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#            carroceria  plazas potencia  puertas   color  \
# 0            Familiar     5.0   130 cv        5  BLANCO
# 1        Todo Terreno     5.0   197 cv        5    AZUL
# 2         Monovolumen     5.0   131 cv        5   NEGRO
# 3   4x4, SUV o pickup     NaN   136 cv        4   OTROS
# 4   4x4, SUV o pickup     NaN   286 cv        4  BLANCO
# ..                ...     ...      ...      ...     ...
# 75       Todo Terreno     5.0   150 cv        5    GRIS
# 76       Todo Terreno     5.0    90 cv        5    GRIS
# 77       Todo Terreno     5.0   150 cv        5  BLANCO
# 78       Todo Terreno     5.0   125 cv        5    ROJO
# 79            Berlina     NaN   181 cv        5    GRIS
#
#                     precio     vendedor  consumo_medio certificado  \
# 0                 11.990 €  Profesional            NaN          No
# 1                 39.990 €  Profesional            5.5          No
# 2                 18.500 €  Profesional            4.3          No
# 3                 31.460 €  Profesional            NaN          No
# 4                 72.274 €  Profesional            NaN          No
# ..                     ...          ...            ...         ...
# 75                23.900 €  Profesional            5.8          No
# 76  21.290 €\n6%\n19.990 €  Profesional            NaN          No
# 77                29.000 €  Profesional            5.5          No
# 78                19.900 €  Profesional            4.5          No
# 79                38.300 €  Profesional            NaN          No
#
#               fecha_extraccion  referencia marca_sola
# 0   2025-02-17 19:26:27.595606    15276957    PEUGEOT
# 1   2025-02-17 19:26:35.003246    15168174      VOLVO
# 2   2025-02-17 19:26:44.036638    13903932    PEUGEOT
# 3   2025-02-17 19:26:52.390413    15317252        KIA
# 4   2025-02-17 19:27:07.527248    15218308       AUDI
# ..                         ...         ...        ...
# 75  2025-02-17 19:37:41.617133    15066087       SEAT
# 76  2025-02-17 19:37:49.595653    15390517    RENAULT
# 77  2025-02-17 19:37:59.121730    15063293      CUPRA
# 78  2025-02-17 19:38:08.024708    15440616       FORD
# 79  2025-02-17 19:38:16.024757    15238745    PEUGEOT
#
# [80 rows x 19 columns]

# %%
df["consumo_medio"].value_counts()
# Out:
# consumo_medio
# 5.5    3
# 5.8    3
# 4.9    3
# 5.4    2
# 4.3    2
# 4.6    2
# 4.8    2
# 4.0    1
# 5.0    1
# 4.2    1
# 6.1    1
# 4.7    1
# 7.0    1
# 3.7    1
# 3.2    1
# 3.8    1
# 1.4    1
# 5.7    1
# 4.5    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo_titulo         80 non-null     object
#  1   localizacion          80 non-null     object
#  2   kilometraje           80 non-null     int64
#  3   combustible           79 non-null     object
#  4   distintivo_ambiental  71 non-null     object
#  5   garantia              80 non-null     float64
#  6   cambio                80 non-null     object
#  7   carroceria            80 non-null     object
#  8   plazas                64 non-null     float64
#  9   potencia              80 non-null     object
#  10  puertas               80 non-null     int64
#  11  color                 80 non-null     object
#  12  precio                80 non-null     object
#  13  vendedor              80 non-null     object
#  14  consumo_medio         29 non-null     float64
#  15  certificado           80 non-null     object
#  16  fecha_extraccion      80 non-null     object
#  17  referencia            80 non-null     int64
#  18  marca_sola            80 non-null     object
#  19  mes_matricula         80 non-null     int64
#  20  anio_matricula        80 non-null     int64
#  21  vendedor_profesional  80 non-null     string
# dtypes: float64(3), int64(5), object(13), string(1)
# memory usage: 13.9+ KB

# %%
df["precio"].unique()
# Out:
# array(['11.990 €', '39.990 €', '18.500 €', '31.460 €', '72.274 €',
#        '72.040 €', '11.900 €', '28.887 €', '35.674 €', '17.900 €',
#        '49.894 €', '73.687 €', '28.654 €', '30.483 €', '7.000 €',
#        '38.729 €', '39.900 €', '23.990 €', '44.900 €', '43.900 €',
#        '21.900 €', '79.300 €\n6%\n74.300 €', '28.900 €', '25.950 €',
#        '16.900 €', '34.900 €', '38.850 €', '19.500 €', '54.900 €',
#        '14.500 €', '9.990 €', '14.990 €', '30.900 €', '33.900 €',
#        '9.490 €', '26.500 €', '18.900 €', '24.990 €', '27.900 €',
#        '41.900 €', '9.900 €', '29.900 €', '35.900 €', '19.300 €',
#        '20.900 €', '42.000 €', '20.500 €', '38.500 €', '45.900 €',
#        '20.990 €', '46.900 €', '15.500 €', '19.990 €', '44.990 €',
#        '23.500 €', '13.990 €', '24.500 €', '10.990 €', '17.500 €',
#        '25.490 €', '21.500 €', '13.990 €\n4%\n13.490 €', '23.900 €',
#        '21.290 €\n6%\n19.990 €', '29.000 €', '19.900 €', '38.300 €'],
#       dtype=object)

# %%
df['precio'] = df['precio'].str.replace('.', '').str.replace(' €', '')
df['precio'] = df['precio'].str.split('\n').str[0]
df['precio'] = pd.to_numeric(df['precio'], errors='coerce')

# %%
df["cambio"].unique()
# Out:
# array(['Manual', 'Automático'], dtype=object)

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#            carroceria  plazas potencia  puertas   color  precio     vendedor  \
# 0            Familiar     5.0   130 cv        5  BLANCO   11990  Profesional
# 1        Todo Terreno     5.0   197 cv        5    AZUL   39990  Profesional
# 2         Monovolumen     5.0   131 cv        5   NEGRO   18500  Profesional
# 3   4x4, SUV o pickup     NaN   136 cv        4   OTROS   31460  Profesional
# 4   4x4, SUV o pickup     NaN   286 cv        4  BLANCO   72274  Profesional
# ..                ...     ...      ...      ...     ...     ...          ...
# 75       Todo Terreno     5.0   150 cv        5    GRIS   23900  Profesional
# 76       Todo Terreno     5.0    90 cv        5    GRIS   21290  Profesional
# 77       Todo Terreno     5.0   150 cv        5  BLANCO   29000  Profesional
# 78       Todo Terreno     5.0   125 cv        5    ROJO   19900  Profesional
# 79            Berlina     NaN   181 cv        5    GRIS   38300  Profesional
#
#     consumo_medio certificado            fecha_extraccion  referencia  \
# 0             NaN          No  2025-02-17 19:26:27.595606    15276957
# 1             5.5          No  2025-02-17 19:26:35.003246    15168174
# 2             4.3          No  2025-02-17 19:26:44.036638    13903932
# 3             NaN          No  2025-02-17 19:26:52.390413    15317252
# 4             NaN          No  2025-02-17 19:27:07.527248    15218308
# ..            ...         ...                         ...         ...
# 75            5.8          No  2025-02-17 19:37:41.617133    15066087
# 76            NaN          No  2025-02-17 19:37:49.595653    15390517
# 77            5.5          No  2025-02-17 19:37:59.121730    15063293
# 78            4.5          No  2025-02-17 19:38:08.024708    15440616
# 79            NaN          No  2025-02-17 19:38:16.024757    15238745
#
#    marca_sola
# 0     PEUGEOT
# 1       VOLVO
# 2     PEUGEOT
# 3         KIA
# 4        AUDI
# ..        ...
# 75       SEAT
# 76    RENAULT
# 77      CUPRA
# 78       FORD
# 79    PEUGEOT
#
# [80 rows x 19 columns]

# %%
df["potencia"].unique()
# Out:
# array(['130 cv', '197 cv', '131 cv', '136 cv', '286 cv', '340 cv',
#        '70 cv', '190 cv', '100 cv', '150 cv', '140 cv', '184 cv',
#        '115 cv', '388 cv', '141 cv', '170 cv', '110 cv', '313 cv',
#        '129 cv', '125 cv', '205 cv', '116 cv', '120 cv', '82 cv',
#        '265 cv', '109 cv', '225 cv', '180 cv', '95 cv', '80 cv', '231 cv',
#        '90 cv', '181 cv'], dtype=object)

# %%
df['potencia'] = df['potencia'].str.replace(' cv', '')
df['potencia'] = pd.to_numeric(df['potencia'], errors='coerce')

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#            carroceria  plazas  potencia  puertas   color  precio     vendedor  \
# 0            Familiar     5.0       130        5  BLANCO   11990  Profesional
# 1        Todo Terreno     5.0       197        5    AZUL   39990  Profesional
# 2         Monovolumen     5.0       131        5   NEGRO   18500  Profesional
# 3   4x4, SUV o pickup     NaN       136        4   OTROS   31460  Profesional
# 4   4x4, SUV o pickup     NaN       286        4  BLANCO   72274  Profesional
# ..                ...     ...       ...      ...     ...     ...          ...
# 75       Todo Terreno     5.0       150        5    GRIS   23900  Profesional
# 76       Todo Terreno     5.0        90        5    GRIS   21290  Profesional
# 77       Todo Terreno     5.0       150        5  BLANCO   29000  Profesional
# 78       Todo Terreno     5.0       125        5    ROJO   19900  Profesional
# 79            Berlina     NaN       181        5    GRIS   38300  Profesional
#
#     consumo_medio certificado            fecha_extraccion  referencia  \
# 0             NaN          No  2025-02-17 19:26:27.595606    15276957
# 1             5.5          No  2025-02-17 19:26:35.003246    15168174
# 2             4.3          No  2025-02-17 19:26:44.036638    13903932
# 3             NaN          No  2025-02-17 19:26:52.390413    15317252
# 4             NaN          No  2025-02-17 19:27:07.527248    15218308
# ..            ...         ...                         ...         ...
# 75            5.8          No  2025-02-17 19:37:41.617133    15066087
# 76            NaN          No  2025-02-17 19:37:49.595653    15390517
# 77            5.5          No  2025-02-17 19:37:59.121730    15063293
# 78            4.5          No  2025-02-17 19:38:08.024708    15440616
# 79            NaN          No  2025-02-17 19:38:16.024757    15238745
#
#    marca_sola  peninsula_y_baleares
# 0     PEUGEOT                  True
# 1       VOLVO                  True
# 2     PEUGEOT                  True
# 3         KIA                  True
# 4        AUDI                  True
# ..        ...                   ...
# 75       SEAT                  True
# 76    RENAULT                  True
# 77      CUPRA                  True
# 78       FORD                  True
# 79    PEUGEOT                  True
#
# [80 rows x 20 columns]

# %%
fuera_de_peninsula_baleares = ["Tenerife", "Las Palmas", "Ceuta", "Melilla"]
df['peninsula_y_baleares'] = True
df.loc[df['localizacion'].isin(fuera_de_peninsula_baleares), 'peninsula_y_baleares'] = False

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0        156000      Diesel                    C      12.0      Manual
# 1         95000      Diesel                  ECO      12.0  Automático
# 2        115000      Diesel                    C      12.0      Manual
# 3         21470         NaN                  NaN      12.0  Automático
# 4         17290      Diésel                  NaN      12.0  Automático
# ..          ...         ...                  ...       ...         ...
# 75        71800    Gasolina                    C      24.0      Manual
# 76        18426    Gasolina                    C      12.0      Manual
# 77         3000    Gasolina                    C      36.0  Automático
# 78        35700    Gasolina                    C      12.0      Manual
# 79           50   Eléctrico          0 EMISIONES      24.0  Automático
#
#            carroceria  plazas potencia  puertas   color  precio     vendedor  \
# 0            Familiar     5.0   130 cv        5  BLANCO   11990  Profesional
# 1        Todo Terreno     5.0   197 cv        5    AZUL   39990  Profesional
# 2         Monovolumen     5.0   131 cv        5   NEGRO   18500  Profesional
# 3   4x4, SUV o pickup     NaN   136 cv        4   OTROS   31460  Profesional
# 4   4x4, SUV o pickup     NaN   286 cv        4  BLANCO   72274  Profesional
# ..                ...     ...      ...      ...     ...     ...          ...
# 75       Todo Terreno     5.0   150 cv        5    GRIS   23900  Profesional
# 76       Todo Terreno     5.0    90 cv        5    GRIS   21290  Profesional
# 77       Todo Terreno     5.0   150 cv        5  BLANCO   29000  Profesional
# 78       Todo Terreno     5.0   125 cv        5    ROJO   19900  Profesional
# 79            Berlina     NaN   181 cv        5    GRIS   38300  Profesional
#
#     consumo_medio certificado            fecha_extraccion  referencia  \
# 0             NaN          No  2025-02-17 19:26:27.595606    15276957
# 1             5.5          No  2025-02-17 19:26:35.003246    15168174
# 2             4.3          No  2025-02-17 19:26:44.036638    13903932
# 3             NaN          No  2025-02-17 19:26:52.390413    15317252
# 4             NaN          No  2025-02-17 19:27:07.527248    15218308
# ..            ...         ...                         ...         ...
# 75            5.8          No  2025-02-17 19:37:41.617133    15066087
# 76            NaN          No  2025-02-17 19:37:49.595653    15390517
# 77            5.5          No  2025-02-17 19:37:59.121730    15063293
# 78            4.5          No  2025-02-17 19:38:08.024708    15440616
# 79            NaN          No  2025-02-17 19:38:16.024757    15238745
#
#    marca_sola  peninsula_y_baleares
# 0     PEUGEOT                  True
# 1       VOLVO                  True
# 2     PEUGEOT                  True
# 3         KIA                  True
# 4        AUDI                  True
# ..        ...                   ...
# 75       SEAT                  True
# 76    RENAULT                  True
# 77      CUPRA                  True
# 78       FORD                  True
# 79    PEUGEOT                  True
#
# [80 rows x 20 columns]

# %%
df["certificado"].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
df["certificado"] = df["certificado"].replace("No", False)
df["certificado"] = df["certificado"].replace("Sí", True)
df["certificado"] = df["certificado"].astype(bool)

# %%
df['fecha_extraccion'] = pd.to_datetime(df['fecha_extraccion'])

# %%
df.drop(columns=["vendedor_profesional", "mes_matricula", "anio_matricula"])
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#     kilometraje combustible distintivo_ambiental  garantia  cambio_automatico  \
# 0        156000      Diesel                    C      12.0              False
# 1         95000      Diesel                  ECO      12.0               True
# 2        115000      Diesel                    C      12.0              False
# 3         21470         NaN                  NaN      12.0               True
# 4         17290      Diésel                  NaN      12.0               True
# ..          ...         ...                  ...       ...                ...
# 75        71800    Gasolina                    C      24.0              False
# 76        18426    Gasolina                    C      12.0              False
# 77         3000    Gasolina                    C      36.0               True
# 78        35700    Gasolina                    C      12.0              False
# 79           50   Eléctrico          0 EMISIONES      24.0               True
#
#            carroceria  plazas  potencia  puertas   color  precio     vendedor  \
# 0            Familiar     5.0       130        5  BLANCO   11990  Profesional
# 1        Todo Terreno     5.0       197        5    AZUL   39990  Profesional
# 2         Monovolumen     5.0       131        5   NEGRO   18500  Profesional
# 3   4x4, SUV o pickup     NaN       136        4   OTROS   31460  Profesional
# 4   4x4, SUV o pickup     NaN       286        4  BLANCO   72274  Profesional
# ..                ...     ...       ...      ...     ...     ...          ...
# 75       Todo Terreno     5.0       150        5    GRIS   23900  Profesional
# 76       Todo Terreno     5.0        90        5    GRIS   21290  Profesional
# 77       Todo Terreno     5.0       150        5  BLANCO   29000  Profesional
# 78       Todo Terreno     5.0       125        5    ROJO   19900  Profesional
# 79            Berlina     NaN       181        5    GRIS   38300  Profesional
#
#     consumo_medio  certificado           fecha_extraccion  referencia  \
# 0             NaN        False 2025-02-17 19:26:27.595606    15276957
# 1             5.5        False 2025-02-17 19:26:35.003246    15168174
# 2             4.3        False 2025-02-17 19:26:44.036638    13903932
# 3             NaN        False 2025-02-17 19:26:52.390413    15317252
# 4             NaN        False 2025-02-17 19:27:07.527248    15218308
# ..            ...          ...                        ...         ...
# 75            5.8        False 2025-02-17 19:37:41.617133    15066087
# 76            NaN        False 2025-02-17 19:37:49.595653    15390517
# 77            5.5        False 2025-02-17 19:37:59.121730    15063293
# 78            4.5        False 2025-02-17 19:38:08.024708    15440616
# 79            NaN        False 2025-02-17 19:38:16.024757    15238745
#
#    marca_sola  peninsula_y_baleares
# 0     PEUGEOT                  True
# 1       VOLVO                  True
# 2     PEUGEOT                  True
# 3         KIA                  True
# 4        AUDI                  True
# ..        ...                   ...
# 75       SEAT                  True
# 76    RENAULT                  True
# 77      CUPRA                  True
# 78       FORD                  True
# 79    PEUGEOT                  True
#
# [80 rows x 20 columns]

# %%
df.rename(columns={'cambio': 'cambio_automatico'}, inplace=True)
df['cambio_automatico'] = df['cambio_automatico'].apply(lambda x: True if x == 'Automático' else False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   modelo_titulo         80 non-null     object
#  1   localizacion          80 non-null     object
#  2   kilometraje           80 non-null     int64
#  3   combustible           79 non-null     object
#  4   distintivo_ambiental  71 non-null     object
#  5   garantia              80 non-null     float64
#  6   cambio                80 non-null     object
#  7   carroceria            80 non-null     object
#  8   plazas                64 non-null     float64
#  9   potencia              80 non-null     int64
#  10  puertas               80 non-null     int64
#  11  color                 80 non-null     object
#  12  precio                80 non-null     int64
#  13  vendedor              80 non-null     object
#  14  consumo_medio         29 non-null     float64
#  15  certificado           80 non-null     bool
#  16  fecha_extraccion      80 non-null     datetime64[ns]
#  17  referencia            80 non-null     int64
#  18  marca_sola            80 non-null     object
#  19  mes_matricula         80 non-null     int64
#  20  anio_matricula        80 non-null     int64
#  21  vendedor_profesional  80 non-null     string
#  22  peninsula_y_baleares  80 non-null     bool
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(7), object(9), string(1)
# memory usage: 13.4+ KB
