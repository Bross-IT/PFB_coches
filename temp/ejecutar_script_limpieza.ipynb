# %%
import pandas as pd

# este es el csv de 464 registros
df = pd.read_csv("../data/coches_segunda_mano-19-02-2025.csv")
df
# Out:
#                                                   marca     anio localizacion  \
# 0                              PEUGEOT 308 1.4 95cv 5p.  05/2009       Lleida
# 1     SEAT León ST 1.6 TDI CR 85 kW (115 CV) Start&S...  06/2020       Lleida
# 2                  PEUGEOT 308 1.5BlueHDi S&S Style 130  09/2019       Lleida
# 3         OPEL Grandland X Grand Land 1.6CDTI Selective  10/2018       Lleida
# 4             AUDI A3 Sportback Sportback 35 TFSI 150cv  02/2021       Lleida
# ...                                                 ...      ...          ...
# 7899                      AUDI Q2 30 TFSI Advanced 81kW  06/2023       Madrid
# 7900          VOLKSWAGEN T-Cross 1.0 TSI Life 85kW Aut.  04/2024       Madrid
# 7901                 VOLKSWAGEN T-Cross 1.0 TSI Advance  06/2022       Madrid
# 7902           VOLKSWAGEN Touran 2.0TDI Life DSG7 110kW  12/2024       Madrid
# 7903                 VOLKSWAGEN Taigo 1.0 TSI Life 81kW  03/2024       Madrid
#
# ...

# %%
df_conces = pd.read_csv("../data/concesionarios.csv")
df_conces
# Out:
#                           nombre                                        calle  \
# 0     --AUTOMOVILES VIA NORTE --            Calle: C/ Rosalia De Castro 7 - 9
# 1                    *ACS MOTOR*   Calle: Carretera Villanueva De La Jara, 25
# 2                   + QUE COCHES                       Calle: Avda Pio Xii 85
# 3                       11ELEVEN                 Calle: Concertar Cita Previa
# 4                13 Premium Cars  Calle: Cars Carrer Benito Pérez Galdós, 27,
# ...                          ...                                          ...
# 4076                     ZENCARS            Calle: Atendemos Con Cita Previa.
# 4077  ZENTRO MACHINE- CASE, S.A.                                          NaN
# 4078            ZOANSA TAILERRAK    Calle: Pol. Ind. Alkaiaga, C. Banarta, 2,
# 4079              ZOE AUTOMOCION                       Calle: Calle Greco S/N
# 4080              Zylautos Motor                 Calle: V Real De Madrid 129,
#
# ...

# %%
df_conces.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4081 entries, 0 to 4080
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nombre         4081 non-null   object
#  1   calle          3879 non-null   object
#  2   municipio      3879 non-null   object
#  3   provincia      4078 non-null   object
#  4   codigo_postal  3879 non-null   object
# dtypes: object(5)
# memory usage: 159.5+ KB

# %%
# Obtener la longitud de cada cadena
longitudes = df_conces[~df_conces["calle"].isna()]["calle"].apply(len)

# Obtener la longitud máxima
longitud_maxima = longitudes.max()

longitud_maxima
# Out:
# np.int64(91)

# %%
df["consumo_medio"].unique()
# Out:
# array([nan, 'Consumo medio\n3,60\nlitros/100 km',
#        'Consumo medio\n4,90\nlitros/100 km',
#        'Consumo medio\n5,10\nlitros/100 km',
#        'Consumo medio\n5,60\nlitros/100 km',
#        'Consumo medio\n3,90\nlitros/100 km',
#        'Consumo medio\n4,40\nlitros/100 km',
#        'Consumo medio\n7,40\nlitros/100 km',
#        'Consumo medio\n9,10\nlitros/100 km',
#        'Consumo medio\n5,20\nlitros/100 km',
#        'Consumo medio\n3,20\nlitros/100 km',
#        'Consumo medio\n8,40\nlitros/100 km',
#        'Consumo medio\nlitros/100 km',
#        'Consumo medio\n4,00\nlitros/100 km',
#        'Consumo medio\n7,50\nlitros/100 km',
#        'Consumo medio\n4,80\nlitros/100 km',
#        'Consumo medio\n3,70\nlitros/100 km',
#        'Consumo medio\n3,80\nlitros/100 km',
#        'Consumo medio\n0,00\nlitros/100 km',
#        'Consumo medio\n12,10\nlitros/100 km',
#        'Consumo medio\n4,60\nlitros/100 km',
#        'Consumo medio\n6,30\nlitros/100 km',
# ...

# %%
import sys
import os

notebook_path = os.path.abspath(".")
sys.path.append(os.path.abspath(os.path.join(notebook_path, '..', 'src')))

from limpieza import limpia

df_limpio = limpia.limpiar_csv("../data/coches_segunda_mano-19-02-2025.csv")

# %%
df_limpio
# Out:
#                                           modelo_titulo provincia kilometraje  \
# 0                                      308 1.4 95cv 5p.    Lleida      142137
# 1     León ST 1.6 TDI CR 85 kW (115 CV) Start&Stop S...    Lleida      106736
# 2                          308 1.5BlueHDi S&S Style 130    Lleida       68314
# 3              Grandland X Grand Land 1.6CDTI Selective    Lleida       55531
# 4                  A3 Sportback Sportback 35 TFSI 150cv    Lleida       75800
# ...                                                 ...       ...         ...
# 7847          Q2 ADVANCED 30 TFSI 81(110) KW(CV) 6 VEL.    Murcia       56640
# 7848                       Golf 2.0TDI Sport DSG7 110kW    Madrid       42000
# 7849                           A6 Avant 40 TDI S tronic    Murcia       24304
# 7902                      Touran 2.0TDI Life DSG7 110kW    Madrid        5000
# 7903                            Taigo 1.0 TSI Life 81kW    Madrid        5000
#
# ...

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4778 entries, 0 to 7903
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   modelo_titulo                4778 non-null   object
#  1   provincia                    4778 non-null   object
#  2   kilometraje                  4778 non-null   object
#  3   combustible                  4751 non-null   object
#  4   distintivo_ambiental         4377 non-null   object
#  5   garantia                     4778 non-null   float64
#  6   cambio_automatico            4778 non-null   bool
#  7   carroceria                   4774 non-null   object
#  8   plazas                       3241 non-null   float64
#  9   potencia                     4753 non-null   float64
#  10  puertas                      4778 non-null   int64
#  11  color                        4778 non-null   object
#  12  precio                       4777 non-null   float64
# ...

# %%
df_limpio["consumo_medio"].isna().sum()
# Out:
# np.int64(1739)

# %%
df_limpio["consumo_medio"].unique()
# Out:
# array([ nan,  3.6,  4.9,  5.1,  5.6,  3.9,  4.4,  7.4,  9.1,  5.2,  3.2,
#         8.4,  4. ,  7.5,  4.8,  3.7,  3.8,  0. , 12.1,  4.6,  6.3,  1.7,
#         4.2,  6. ,  1.4,  1.9,  5.8,  5. , 10.4,  7.2,  6.4,  5.3,  5.7,
#         6.6,  8.1,  4.7,  5.4,  4.3,  3.5,  6.1,  6.5,  9.6, 10.5,  8. ,
#        11.8,  6.8,  7. ,  9.3,  8.6,  4.5,  3.3,  5.9,  6.7,  4.1,  7.3,
#        11.1,  8.8,  7.1,  7.9,  7.6,  6.9,  5.5,  2.5,  1.8,  9.4,  2.2,
#         6.2, 11.4, 16.2,  3.4, 20.5, 13.1,  9.2,  8.2, 12.7, 11.3,  7.7,
#         9.5, 10.8,  9.9, 13.2,  2. ,  1.6,  8.7,  9. ,  2.8,  7.8, 11.5,
#        11. , 12.5, 16. ,  3.1, 10.3,  9.8,  8.3,  8.9, 11.6,  2.7,  2.1,
#         1.2, 10.9, 12.8,  2.6, 13.8])

# %%
urls_imagenes = df_limpio["ruta_imagen"].unique().tolist()

# %%
# Obtener la longitud de cada cadena en la columna "url"
longitudes = df_limpio[~df_limpio["ruta_imagen"].isna()]["ruta_imagen"].apply(len)

# Obtener la longitud máxima
longitud_maxima = longitudes.max()

longitud_maxima
# Out:
# np.int64(63)

# %%
len(urls_imagenes[129])
# Out:
# 63

# %%
df_limpio[df_limpio["comunidad"].isna()]
# Out:
#                                   modelo_titulo       provincia kilometraje  \
# 48               Clase C Estate 300 e 9G-Tronic        Tenerife       26200
# 66      Coupé Deportivo Automático de 3 Puertas        Tenerife       83800
# 69              C4 Familiar Manual de 5 Puertas        Tenerife      129000
# 291         Kamiq 1.0 TSI Monte Carlo 85kW DSG7        Tenerife        3858
# 292                         Tiguan 1.5 TSI 96kW        Tenerife       40299
# ...                                         ...             ...         ...
# 6678                                   i3 120Ah  Islas Baleares       97088
# 6679    Ceed 1.6 GDI PHEV EMOTION TOURER 141 5P  Islas Baleares       28170
# 6681      Vitara 1.5 HEV GLE STRONG AUTO 116 5P  Islas Baleares       34622
# 6682      Ceed 1.6 GDI PHEV ETECH TOURER 141 5P  Islas Baleares       20139
# 6683  Q3 1.5 35 TFSI S TRONIC BLACK LINE 150 5P  Islas Baleares       26565
#
# ...

# %%
longitudes = df_limpio["nombre_vendedor_profesional"].apply(lambda x: len(x) if pd.notna(x) else 0)


# Obtener la longitud máxima
longitud_maxima = longitudes.max()

longitud_maxima
# Out:
# np.int64(50)

# %%
# con esto sabréis la ruta actual

import os

ruta_actual = os.getcwd()

print(f"La ruta actual de trabajo es: {ruta_actual}")
# Out:
# La ruta actual de trabajo es: /home/bross/Codigo_HAB/PFB_coches/PFB_coches/temp
