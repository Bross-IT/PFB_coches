# %%
# quizás haya que comentar línea de src/__init__.py para que funcione esto

# %%
import pandas as pd

# leer el csv de 300 registros
df = pd.read_csv("../data/coches_segunda_mano-18-02-2025.csv")
df
# Out:
#                                                  marca     anio localizacion  \
# 0    FORD Mustang 5.0 Ti-VCT V8+714 CV+RECARO+KAMER...  06/2019       Madrid
# 1         FORD Mustang 5.0 Ti-VCT V8 GT350 LOOK Shelby  01/2019       Madrid
# 2                         FORD Focus 2.3 Ecoboost ST 3  12/2020       Madrid
# 3                             BMW X4 xDrive 20dA xLine  04/2024      Granada
# 4                                   BMW X4 xDrive 20dA  02/2020      Granada
# ..                                                 ...      ...          ...
# 459                RENAULT Clio Blue dCi Business 74kW  12/2021       Málaga
# 460               RENAULT Mégane 1.5dCi Blue Life 85kW  12/2021       Málaga
# 461                VOLKSWAGEN Polo 1.0 TSI R-Line 70kW  12/2021       Málaga
# 462                          BMW Serie 3 318dA M Sport  05/2024       Málaga
# 463                                   BMW Serie 1 116d  03/2019       Málaga
#
# ...

# %%
from limpieza import limpia

df_limpio = limpia.limpiar_csv("../data/coches_segunda_mano-18-02-2025.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from limpieza import limpia
#       3 df_limpio = limpia.limpiar_csv("../data/coches_segunda_mano-18-02-2025.csv")
#
# ModuleNotFoundError: No module named 'limpieza'

# %%
df_limpio
# Out:
#                                         modelo_titulo localizacion  \
# 0                   308 SW 1.5 BlueHDi S&S Allure 130      Sevilla
# 1                           XC60 B4 R-Design AWD Aut.      Sevilla
# 2          Rifter 1.5BlueHDi S&S Long Active Pack 130      Almería
# 3   Sportage Todoterreno 136cv Automático de 4 Pue...     Valencia
# 4                                           Q8 s-line     Valencia
# ..                                                ...          ...
# 75                      Tarraco 1.5 TSI S&S Style 150      Almería
# 76                             Captur TCe Techno 67kW       Madrid
# 77                          Formentor 1.5 TSI 150 DSG      Almería
# 78                    Puma 1.0 EcoBoost ST-Line X 125     Albacete
# 79                408 1.6 PHEV 133KW GT E-AUTO 181 5P       Toledo
#
#    kilometraje combustible distintivo_ambiental  garantia  cambio_automatico  \
# 0       156000      Diesel                    C      12.0              False
# ...

# %%
# con esto sabréis la ruta actual

import os

ruta_actual = os.getcwd()

print(f"La ruta actual de trabajo es: {ruta_actual}")
# Out:
# La ruta actual de trabajo es: /home/bross/Codigo_HAB/PFB_coches
