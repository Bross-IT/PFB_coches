# %%
import pandas as pd

# este es el csv de 464 registros
df = pd.read_csv("../data/coches_segunda_mano-18-02-2025.csv")
df
# Out:
#                                                  marca     anio localizacion  \
# 0    FORD Mustang 5.0 Ti-VCT V8+714 CV+RECARO+KAMER...  06/2019       Madrid
# 1         FORD Mustang 5.0 Ti-VCT V8 GT350 LOOK Shelby  01/2019       Madrid
# 2                         FORD Focus 2.3 Ecoboost ST 3  12/2020       Madrid
# 3                             BMW X4 xDrive 20dA xLine  04/2024      Granada
# 4                                   BMW X4 xDrive 20dA  02/2020      Granada
# ..                                                 ...      ...          ...
# 459                RENAULT Clio Blue dCi Business 74kW  12/2021       Málaga
# 460               RENAULT Mégane 1.5dCi Blue Life 85kW  12/2021       Málaga
# 461                VOLKSWAGEN Polo 1.0 TSI R-Line 70kW  12/2021       Málaga
# 462                          BMW Serie 3 318dA M Sport  05/2024       Málaga
# 463                                   BMW Serie 1 116d  03/2019       Málaga
#
#     kilometraje combustible distintivo_ambiental  garantia      cambio  \
# 0     23.000 km    Gasolina                    C  12 meses  Automático
# 1     41.000 km    Gasolina                    C  12 meses      Manual
# 2     89.552 km    Gasolina                    C  12 meses      Manual
# 3     25.600 km      Diesel                  ECO  24 meses  Automático
# 4     95.800 km      Diesel                    C  12 meses  Automático
# ..          ...         ...                  ...       ...         ...
# 459   54.000 km      Diesel                    C  12 meses      Manual
# 460   47.000 km      Diesel                    C  12 meses      Manual
# 461   21.000 km    Gasolina                    C  12 meses      Manual
# 462   13.000 km      Diesel                  ECO  24 meses  Automático
# 463   52.000 km      Diesel                    C  12 meses      Manual
#
#     carroceria      plazas potencia    puertas               color    precio  \
# 0      Pequeño         NaN   714 cv  3 Puertas   gris / Metalizado  64.900 €
# 1      Pequeño         NaN   450 cv  3 Puertas  negro / Metalizado  43.000 €
# 2      Berlina  5 asientos   280 cv  5 Puertas  negro / Metalizado  29.690 €
# 3        Coupe  5 asientos   190 cv  5 Puertas                Azul  57.900 €
# 4        Coupe  5 asientos   190 cv  5 Puertas                Rojo  39.490 €
# ..         ...         ...      ...        ...                 ...       ...
# 459    Berlina  5 asientos   100 cv  5 Puertas              Blanco  15.800 €
# 460    Berlina  5 asientos   115 cv  5 Puertas              Blanco  17.800 €
# 461    Berlina  5 asientos    95 cv  5 Puertas              Blanco  19.300 €
# 462    Berlina  5 asientos   150 cv  4 Puertas                Gris  42.300 €
# 463    Berlina  5 asientos   116 cv  5 Puertas              Blanco  19.300 €
#
#                               vendedor                       consumo_medio  \
# 0      GERMACARS MOBILITY\nProfesional                                 NaN
# 1      GERMACARS MOBILITY\nProfesional                                 NaN
# 2      GERMACARS MOBILITY\nProfesional  Consumo medio\n7,60\nlitros/100 km
# 3    FRAMACAR AUTOMOVILES\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 4    FRAMACAR AUTOMOVILES\nProfesional  Consumo medio\n5,00\nlitros/100 km
# ..                                 ...                                 ...
# 459        MARTINSA MOTOR\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 460        MARTINSA MOTOR\nProfesional  Consumo medio\n3,90\nlitros/100 km
# 461        MARTINSA MOTOR\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 462        MARTINSA MOTOR\nProfesional  Consumo medio\n0,00\nlitros/100 km
# 463        MARTINSA MOTOR\nProfesional  Consumo medio\n3,80\nlitros/100 km
#
#     certificado            fecha_extraccion   referencia
# 0            No  2025-02-18 11:15:17.922326  ref15231216
# 1            No  2025-02-18 11:15:45.618010  ref15221898
# 2            No  2025-02-18 11:15:53.589509  ref15036704
# 3            No  2025-02-18 11:16:00.414864  ref15227266
# 4            No  2025-02-18 11:16:07.869053  ref15304683
# ..          ...                         ...          ...
# 459          Si  2025-02-18 12:17:32.250314  ref15319497
# 460          Si  2025-02-18 12:17:37.597308  ref15318805
# 461          Si  2025-02-18 12:17:43.644339  ref15318499
# 462          Si  2025-02-18 12:17:50.859351  ref15303542
# 463          Si  2025-02-18 12:17:57.066789  ref15303360
#
# [464 rows x 19 columns]

# %%
df[df["localizacion"].isna()]
# Out:
#                                         marca     anio localizacion  \
# 371  MERCEDES-BENZ Clase V EQV 300 Larga e100  04/2022          NaN
# 372                     MERCEDES-BENZ EQB 250  07/2023          NaN
# 381            NISSAN Juke 1.6 Acenta 4x2 112  02/2019          NaN
#
#     kilometraje          combustible distintivo_ambiental  garantia  \
# 371    8.540 km            Eléctrico          0 EMISIONES        Sí
# 372   14.720 km  Corriente eléctrica          0 EMISIONES  36 meses
# 381   90.336 km             Gasolina                    C  12 meses
#
#          cambio    carroceria      plazas potencia    puertas  \
# 371  Automático       Pequeño         NaN   204 cv  5 Puertas
# 372  Automático  Todo Terreno  5 asientos   190 cv  5 Puertas
# 381      Manual  Todo Terreno  5 asientos   112 cv  5 Puertas
#
#                         color    precio  \
# 371  gris selenita metalizado  49.900 €
# 372   Gris montaña metalizado  39.990 €
# 381                    Blanco  13.790 €
#
#                                       vendedor  \
# 371  MERCEDES CANARIAS LAS PALMAS\nProfesional
# 372  MERCEDES CANARIAS LAS PALMAS\nProfesional
# 381                   SHOPING CAR\nProfesional
#
#                           consumo_medio certificado  \
# 371                                 NaN          Si
# 372  Consumo medio\n0,00\nlitros/100 km          Si
# 381  Consumo medio\n6,90\nlitros/100 km          No
#
#                fecha_extraccion   referencia
# 371  2025-02-18 12:05:16.733564  ref13800403
# 372  2025-02-18 12:05:24.177183  ref14777875
# 381  2025-02-18 12:06:20.489508  ref15401172

# %%
df["localizacion"].unique()
# Out:
# array(['Madrid', 'Granada', 'Vizcaya', 'Málaga', 'Barcelona', 'Sevilla',
#        'Girona', 'Alicante', 'Cádiz', 'Zaragoza', 'Ávila', 'Navarra',
#        'Toledo', 'Valencia', 'Lugo', 'La Rioja', 'Murcia', 'Badajoz',
#        'León', 'Segovia', 'Zamora', nan, 'La Coruña', 'Tarragona',
#        'Albacete', 'Castellón', 'Valladolid'], dtype=object)

# %%
import sys
import os

notebook_path = os.path.abspath(".")
sys.path.append(os.path.abspath(os.path.join(notebook_path, '..', 'src')))

from limpieza import limpia

df_limpio = limpia.limpiar_csv("../data/coches_segunda_mano-18-02-2025.csv")

# %%
df_limpio
# Out:
#                                        modelo_titulo provincia kilometraje  \
# 0    Mustang 5.0 Ti-VCT V8+714 CV+RECARO+KAMERA+LED+    Madrid       23000
# 1            Mustang 5.0 Ti-VCT V8 GT350 LOOK Shelby    Madrid       41000
# 2                            Focus 2.3 Ecoboost ST 3    Madrid       89552
# 3                               X4 xDrive 20dA xLine   Granada       25600
# 4                                     X4 xDrive 20dA   Granada       95800
# ..                                               ...       ...         ...
# 459                      Clio Blue dCi Business 74kW    Málaga       54000
# 460                     Mégane 1.5dCi Blue Life 85kW    Málaga       47000
# 461                         Polo 1.0 TSI R-Line 70kW    Málaga       21000
# 462                            Serie 3 318dA M Sport    Málaga       13000
# 463                                     Serie 1 116d    Málaga       52000
#
#     combustible distintivo_ambiental  garantia  cambio_automatico carroceria  \
# 0      Gasolina                    C      12.0               True    Pequeño
# 1      Gasolina                    C      12.0              False    Pequeño
# 2      Gasolina                    C      12.0              False    Berlina
# 3        Diésel                  ECO      24.0               True      Coupe
# 4        Diésel                    C      12.0               True      Coupe
# ..          ...                  ...       ...                ...        ...
# 459      Diésel                    C      12.0              False    Berlina
# 460      Diésel                    C      12.0              False    Berlina
# 461    Gasolina                    C      12.0              False    Berlina
# 462      Diésel                  ECO      24.0               True    Berlina
# 463      Diésel                    C      12.0              False    Berlina
#
#      plazas  potencia  ...  consumo_medio certificado  \
# 0       NaN     714.0  ...            NaN       False
# 1       NaN     450.0  ...            NaN       False
# 2       5.0     280.0  ...            7.6       False
# 3       5.0     190.0  ...            NaN       False
# 4       5.0     190.0  ...            5.0       False
# ..      ...       ...  ...            ...         ...
# 459     5.0     100.0  ...            NaN        True
# 460     5.0     115.0  ...            3.9        True
# 461     5.0      95.0  ...            NaN        True
# 462     5.0     150.0  ...            NaN        True
# 463     5.0     116.0  ...            3.8        True
#
#               fecha_extraccion  referencia  marca_sola  mes_matricula  \
# 0   2025-02-18 11:15:17.922326    15231216        FORD              6
# 1   2025-02-18 11:15:45.618010    15221898        FORD              1
# 2   2025-02-18 11:15:53.589509    15036704        FORD             12
# 3   2025-02-18 11:16:00.414864    15227266         BMW              4
# 4   2025-02-18 11:16:07.869053    15304683         BMW              2
# ..                         ...         ...         ...            ...
# 459 2025-02-18 12:17:32.250314    15319497     RENAULT             12
# 460 2025-02-18 12:17:37.597308    15318805     RENAULT             12
# 461 2025-02-18 12:17:43.644339    15318499  VOLKSWAGEN             12
# 462 2025-02-18 12:17:50.859351    15303542         BMW              5
# 463 2025-02-18 12:17:57.066789    15303360         BMW              3
#
#     anio_matricula  nombre_vendedor_profesional peninsula_y_baleares  \
# 0             2019           GERMACARS MOBILITY                 True
# 1             2019           GERMACARS MOBILITY                 True
# 2             2020           GERMACARS MOBILITY                 True
# 3             2024         FRAMACAR AUTOMOVILES                 True
# 4             2020         FRAMACAR AUTOMOVILES                 True
# ..             ...                          ...                  ...
# 459           2021               MARTINSA MOTOR                 True
# 460           2021               MARTINSA MOTOR                 True
# 461           2021               MARTINSA MOTOR                 True
# 462           2024               MARTINSA MOTOR                 True
# 463           2019               MARTINSA MOTOR                 True
#
#                comunidad
# 0    Comunidad de Madrid
# 1    Comunidad de Madrid
# 2    Comunidad de Madrid
# 3              Andalucía
# 4              Andalucía
# ..                   ...
# 459            Andalucía
# 460            Andalucía
# 461            Andalucía
# 462            Andalucía
# 463            Andalucía
#
# [464 rows x 24 columns]

# %%
df_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   modelo_titulo                464 non-null    object
#  1   provincia                    461 non-null    object
#  2   kilometraje                  464 non-null    object
#  3   combustible                  464 non-null    object
#  4   distintivo_ambiental         441 non-null    object
#  5   garantia                     464 non-null    float64
#  6   cambio_automatico            464 non-null    bool
#  7   carroceria                   462 non-null    object
#  8   plazas                       427 non-null    float64
#  9   potencia                     461 non-null    float64
#  10  puertas                      464 non-null    int64
#  11  color                        464 non-null    object
#  12  precio                       464 non-null    int64
#  13  vendedor_profesional         464 non-null    bool
#  14  consumo_medio                174 non-null    float64
#  15  certificado                  464 non-null    bool
#  16  fecha_extraccion             464 non-null    datetime64[ns]
#  17  referencia                   464 non-null    int64
#  18  marca_sola                   464 non-null    object
#  19  mes_matricula                464 non-null    int64
#  20  anio_matricula               464 non-null    int64
#  21  nombre_vendedor_profesional  464 non-null    string
#  22  peninsula_y_baleares         464 non-null    bool
#  23  comunidad                    461 non-null    object
# dtypes: bool(4), datetime64[ns](1), float64(4), int64(5), object(9), string(1)
# memory usage: 74.4+ KB

# %%
df_limpio["comunidad"].unique()
# Out:
# array(['Comunidad de Madrid', 'Andalucía', 'País Vasco', 'Cataluña',
#        'Comunidad Valenciana', 'Aragón', 'Castilla y León', 'Navarra',
#        'Castilla-La Mancha', 'Galicia', 'La Rioja', 'Región de Murcia',
#        'Extremadura', nan], dtype=object)

# %%
df_limpio[df_limpio["comunidad"].isna()]
# Out:
#                   modelo_titulo provincia kilometraje combustible  \
# 371  Clase V EQV 300 Larga e100       NaN        8540   Eléctrico
# 372                     EQB 250       NaN       14720   Eléctrico
# 381     Juke 1.6 Acenta 4x2 112       NaN       90336    Gasolina
#
#     distintivo_ambiental  garantia  cambio_automatico    carroceria  plazas  \
# 371          0 EMISIONES      18.0               True       Pequeño     NaN
# 372          0 EMISIONES      36.0               True  Todo Terreno     5.0
# 381                    C      12.0              False  Todo Terreno     5.0
#
#      potencia  ...  consumo_medio certificado           fecha_extraccion  \
# 371     204.0  ...            NaN        True 2025-02-18 12:05:16.733564
# 372     190.0  ...            NaN        True 2025-02-18 12:05:24.177183
# 381     112.0  ...            6.9       False 2025-02-18 12:06:20.489508
#
#      referencia     marca_sola  mes_matricula anio_matricula  \
# 371    13800403  MERCEDES-BENZ              4           2022
# 372    14777875  MERCEDES-BENZ              7           2023
# 381    15401172         NISSAN              2           2019
#
#       nombre_vendedor_profesional peninsula_y_baleares  comunidad
# 371  MERCEDES CANARIAS LAS PALMAS                 True        NaN
# 372  MERCEDES CANARIAS LAS PALMAS                 True        NaN
# 381                   SHOPING CAR                 True        NaN
#
# [3 rows x 24 columns]

# %%
longitudes = df_limpio["nombre_vendedor_profesional"].apply(lambda x: len(x) if pd.notna(x) else 0)


# Obtener la longitud máxima
longitud_maxima = longitudes.max()

longitud_maxima
# Out:
# np.int64(46)

# %%
# con esto sabréis la ruta actual

import os

ruta_actual = os.getcwd()

print(f"La ruta actual de trabajo es: {ruta_actual}")
# Out:
# La ruta actual de trabajo es: /home/bross/Codigo_HAB/PFB_coches/PFB_coches/temp
