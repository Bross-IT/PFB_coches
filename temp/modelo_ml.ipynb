# %%
import pandas as pd
import numpy as np
import pickle

import os
import sys

notebook_path = os.path.abspath(".")
sys.path.append(os.path.abspath(os.path.join(notebook_path, '..', 'src')))

import encoding_func

# %%
df_modelo = pd.read_pickle('../bin/dataframe_ml.pickle')
df_modelo
# Out:
#        kilometraje  cambio_automatico  potencia     marca_sola  \
# 0        11.652696               True  5.252273          VOLVO
# 1         9.615872               True  5.802118  MERCEDES-BENZ
# 2        10.512655               True  5.198497        CITROEN
# 3        10.238387              False  4.615121           JEEP
# 4        12.388398               True  5.484797         JAGUAR
# ...            ...                ...       ...            ...
# 14518    11.643962               True  4.418841          SMART
# 14519    11.341128               True  4.812184         TOYOTA
# 14520    10.072217              False  4.262680           FIAT
# 14521    10.308653               True  5.283204         TOYOTA
# 14522     1.386294               True  4.762174         TOYOTA
#
#        anio_matricula     precio
# 0                   6  10.196194
# 1                   2  11.156251
# 2                   3  10.038936
# 3                   2  10.081676
# 4                  15   8.916104
# ...               ...        ...
# 14518               7   9.158099
# 14519               2  10.105653
# 14520               1   9.391912
# 14521               1  10.542469
# 14522               1  10.126271
#
# [13594 rows x 6 columns]

# %%
with open(f"../bin/marca_sola_precio_encoder.pickle", "rb") as file:
    marca_sola_precio_encoder = pickle.load(file)

with open(f"../bin/min_max_scaler.pickle", "rb") as file:
    min_max_scaler = pickle.load(file)

# %%
TARGET = "precio"

X_train, X_test, y_train, y_test = encoding_func.dividir_dataframe(df_modelo, TARGET, test_size=0.2, random_state=42)

X_train["marca_sola"] = marca_sola_precio_encoder.transform(X_train["marca_sola"])
X_test["marca_sola"] = marca_sola_precio_encoder.transform(X_test["marca_sola"])

X_train = min_max_scaler.transform(X_train)
X_test = min_max_scaler.transform(X_test)

# %%
import time
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
modelos = {
    "Regresión Lineal": LinearRegression(),
    "Árbol de Decisión": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(n_estimators=100, random_state=42),
    "K-Vecinos": KNeighborsRegressor(n_neighbors=5)
}

# %%
resultados = []

for nombre, modelo in modelos.items():
    modelo.fit(X_train, y_train)
    y_pred = modelo.predict(X_test)
    
    resultados.append({
        "Modelo": nombre,
        "MAE": mean_absolute_error(y_test, y_pred),
        "MSE": mean_squared_error(y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred)),
        "R2": r2_score(y_test, y_pred)
    })


df_resultados = pd.DataFrame(resultados).sort_values(by="R2", ascending=False)
df_resultados
# Out:
#               Modelo       MAE       MSE      RMSE        R2
# 2      Random Forest  0.122905  0.033696  0.183565  0.891674
# 3  Gradient Boosting  0.134651  0.037279  0.193078  0.880157
# 0   Regresión Lineal  0.153245  0.050768  0.225317  0.836794
# 1  Árbol de Decisión  0.157667  0.055950  0.236538  0.820133
# 4          K-Vecinos  0.209734  0.084620  0.290895  0.727966

# %%
from sklearn.model_selection import GridSearchCV

parametros_rf = {
    "n_estimators": [100, 150, 200, 250],
    "max_depth": [None, 5],
    "min_samples_split": [8, 10, 12],
    "min_samples_leaf": [4, 6, 8]
}

from sklearn.ensemble import RandomForestRegressor
modelo_rf = RandomForestRegressor(random_state=42)

grid_search_rf = GridSearchCV(
    modelo_rf,
    parametros_rf,
    cv=5,  
    scoring="r2",  
    n_jobs=-1,  
    verbose=2
)

grid_search_rf.fit(X_train, y_train)

print("Mejores hiperparámetros:", grid_search_rf.best_params_)
print("Mejor R2 obtenido:", grid_search_rf.best_score_)

modelo_final_rf = grid_search_rf.best_estimator_
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   2.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   4.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   4.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   4.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   4.6s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   4.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   5.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   3.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   5.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   5.4s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   5.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   4.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   4.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   5.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   3.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   5.8s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   5.5s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   4.2s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   2.2s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   5.3s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   4.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   5.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   3.2s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   4.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   4.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   4.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   3.0s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   3.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   3.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   4.1s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   4.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   4.9s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   4.9s
# [CV] END max_depth=None, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   5.2s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   4.5s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   4.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   4.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   5.1s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   4.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   3.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   3.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   4.0s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.9s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   2.1s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   4.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   4.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   4.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   2.9s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   2.7s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   4.5s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   2.8s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   4.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   3.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   3.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   4.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=150; total time=   1.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   4.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   4.6s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   4.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   4.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=8, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   1.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=200; total time=   2.2s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=100; total time=   1.2s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=12, n_estimators=250; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   1.7s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=200; total time=   2.2s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=8, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=10, n_estimators=250; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.0s[CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   2.1s
#
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   1.7s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=6, min_samples_split=12, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=8, n_estimators=250; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=100; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   1.6s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=150; total time=   1.5s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   1.8s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   1.8s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   1.9s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   2.0s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=200; total time=   1.9s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   2.1s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   1.9s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   1.8s
# [CV] END max_depth=5, min_samples_leaf=8, min_samples_split=12, n_estimators=250; total time=   1.8s
# Mejores hiperparámetros: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 250}
# Mejor R2 obtenido: 0.892239428712075

# %%
importancias = modelo_final_rf.feature_importances_

df_importancias = pd.DataFrame({
                  'Feature': X_train.columns,  
                  'Importance': importancias
                  })

df_importancias = df_importancias.sort_values(by='Importance', ascending=False).reset_index(drop=True)
df_importancias['Feature'] =  df_importancias['Feature'].map( {'potencia': 'Potencia',
                                                                'anio_matricula': 'Año de Matrícula',
                                                                'kilometraje':'Kilometraje',
                                                                'marca_sola': 'Marca',
                                                                'cambio_automatico': 'Cambio Automático'})

df_importancias
# Out:
#              Feature  Importance
# 0           Potencia    0.572482
# 1   Año de Matrícula    0.232717
# 2        Kilometraje    0.110998
# 3              Marca    0.078603
# 4  Cambio Automático    0.005200

# %%
import pickle

with open("../bin/mejor_modelo.pickle", "wb") as archivo:
    pickle.dump(grid_search_rf.best_estimator_, archivo)
