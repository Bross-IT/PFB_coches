# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error
from datetime import datetime
import numpy as np

class MySQLDataLoader:
    def __init__(self, user, password, database, host="localhost"):
        self.connection = mysql.connector.connect(
            host=host,
            user=user,
            password=password,
            database=database
        )
    
    def get_max_fecha_extraccion(self):
        cursor = self.connection.cursor(buffered=True)
        cursor.execute("SELECT MAX(fecha_extraccion) FROM coches_en_venta;")
        result = cursor.fetchone()
        cursor.close()
        return result[0] if result[0] else None
    
    def get_concesionario_count(self):
        cursor = self.connection.cursor(buffered=True)
        cursor.execute("SELECT COUNT(*) FROM concesionario;")
        result = cursor.fetchone()
        cursor.close()
        return result[0]
    
    def insert_ignore(self, table, column, value):
        print(f"tabla {table}, columna {column}, valor {value}")
        cursor = self.connection.cursor(buffered=True)
        query = f"INSERT IGNORE INTO {table} ({column}) VALUES (%s);"
        cursor.execute(query, (value,))
        self.connection.commit()
        
        # Determinar el nombre del ID según la tabla
        campo_id = "modelo" if table == "modelo_titulo" else table
        
        cursor.execute(f"SELECT {campo_id}_id FROM {table} WHERE {column} = %s;", (value,))
        result = cursor.fetchone()
        cursor.close()
        
        return result[0] if result else None

    
    def insert_modelo_titulo(self, marca_id, nombre_modelo):
        cursor = self.connection.cursor(buffered=True)
        query = """
        INSERT IGNORE INTO modelo_titulo (marca_id, nombre_modelo) VALUES (%s, %s)
        """
        cursor.execute(query, (marca_id, nombre_modelo))
        self.connection.commit()
        cursor.execute("SELECT modelo_id FROM modelo_titulo WHERE nombre_modelo = %s AND marca_id = %s;", (nombre_modelo, marca_id))
        result = cursor.fetchone()
        cursor.close()
        return result[0]
    
    def insert_url(self, url):
        cursor = self.connection.cursor(buffered=True)
        query = """
        INSERT INTO urls (url)
        VALUES (%s)
        ON DUPLICATE KEY UPDATE url = VALUES(url);"""
        cursor.execute(query, (url,))
        cursor.execute("SELECT url_id FROM urls WHERE url = %s;", (url,))
        result = cursor.fetchone()
        self.connection.commit()
        cursor.close()
        return result[0]
    
    def insert_ruta_imagen(self, ruta_imagen):
        cursor = self.connection.cursor(buffered=True)
        query = """
        INSERT INTO ruta_imagen (ruta_imagen)
        VALUES (%s)
        ON DUPLICATE KEY UPDATE ruta_imagen = VALUES(ruta_imagen);"""
        cursor.execute(query, (ruta_imagen,))
        cursor.execute("SELECT ruta_imagen_id FROM ruta_imagen WHERE ruta_imagen = %s;", (ruta_imagen,))
        result = cursor.fetchone()
        self.connection.commit()
        cursor.close()
        return result[0]
    
    def get_concesionario_id(self, nombre_concesionario):
        cursor = self.connection.cursor(buffered=True)
        cursor.execute("SELECT concesionario_id FROM concesionario WHERE nombre_concesionario = %s;", (nombre_concesionario,))
        result = cursor.fetchone()
        cursor.close()
        return result[0] if result else None
        
    def process_csv_concesionarios(self, file_path):
        df = pd.read_csv(file_path)

        if len(df) > self.get_concesionario_count():
            for _, row in df.iterrows():
                provincia_id = None
                municipio_id = None
                print(row["nombre"])
                print(row["provincia"])
                print(row["municipio"])
                if pd.notna(row["provincia"]) and row["provincia"] != "":
                    provincia_id = self.insert_ignore("provincia", "nombre_provincia", row["provincia"])
                if pd.notna(row["municipio"]) and row["municipio"] != "":
                    municipio_id = self.insert_ignore("municipio", "nombre_municipio", row["municipio"])

                query = """
                INSERT INTO concesionario (nombre_concesionario, calle, provincia_id, codigo_postal, municipio_id)
                VALUES (%s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE nombre_concesionario = VALUES(nombre_concesionario);"""
                cursor = self.connection.cursor(buffered=True)
                cursor.execute(query, (
                    row["nombre"],
                    row["calle"] if pd.notna(row["calle"]) else None,
                    provincia_id,
                    int(row["codigo_postal"]) if pd.notna(row["codigo_postal"]) else None,
                    municipio_id
                ))
                self.connection.commit()
                cursor.close()
                #break

    def process_csv_coches(self, file_path):
        df = pd.read_csv(file_path, parse_dates=["fecha_extraccion"], dtype={
            "puertas": "Int64", "mes_matricula": "Int64", "anio_matricula": "Int64"
        })
        max_fecha = self.get_max_fecha_extraccion()
        df = df[df["fecha_extraccion"] >= max_fecha] if max_fecha else df

        anio_actual = datetime.now().year
        mes_actual = datetime.now().month

        print("Antes del for")
        
        for _, row in df.iterrows():
            print(row["combustible"])
            combustible_id = self.insert_ignore("combustible", "nombre_combustible", row["combustible"])
            print("antes de marca_Id")
            marca_id = self.insert_ignore("marca", "nombre_marca", row["marca_sola"])
            print(marca_id)
            print(row["modelo_titulo"])
            modelo_id = self.insert_modelo_titulo(marca_id, row["modelo_titulo"])
            print("color")
            color_id = self.insert_ignore("color", "nombre_color", row["color"])
            print("carroceria")
            carroceria_id = self.insert_ignore("carroceria", "nombre_carroceria", row["carroceria"])
            print("distintivo")
            distintivo_ambiental_id = self.insert_ignore("distintivo_ambiental", "nombre_distintivo", row["distintivo_ambiental"])
            print("url")
            url_id = self.insert_url(row["url"])
            print(row["ruta_imagen"])
            if row["ruta_imagen"] != "" and pd.notna(row["ruta_imagen"]):
                ruta_imagen_id = self.insert_ruta_imagen(row["ruta_imagen"])
            else:
                ruta_imagen_id = None
            
            print("concesionario")
            concesionario_id = None
            if row["vendedor_profesional"]:
                print("dentro del if")
                concesionario_id = self.get_concesionario_id(row["nombre_vendedor_profesional"])
            
            print ("Antes del data")

            data = {
                "referencia": row["referencia"],
                "peninsula_baleares": int(row["peninsula_y_baleares"]) if pd.notna(row["peninsula_y_baleares"]) else None,
                "combustible_id": combustible_id,
                "potencia": row["potencia"] if pd.notna(row["potencia"]) else None,
                "cambio_automatico": int(row["cambio_automatico"]) if pd.notna(row["cambio_automatico"]) else None,
                "carroceria_id": carroceria_id,
                "kilometraje": row["kilometraje"] if pd.notna(row["kilometraje"]) else None,
                "distintivo_ambiental_id": distintivo_ambiental_id,
                "color_id": color_id,
                "garantia": row["garantia"] if pd.notna(row["garantia"]) else None,
                "vendedor_profesional": int(row["vendedor_profesional"]) if pd.notna(row["vendedor_profesional"]) else None,
                "plazas": row["plazas"] if pd.notna(row["plazas"]) else None,
                "puertas": row["puertas"] if pd.notna(row["puertas"]) else None,
                "certificado": int(row["certificado"]) if pd.notna(row["certificado"]) else None,
                "fecha_extraccion": row["fecha_extraccion"].strftime('%Y-%m-%d %H:%M:%S'),
                "consumo": row["consumo_medio"] if pd.notna(row["consumo_medio"]) else None,
                "modelo_id": modelo_id,
                "antiguedad": anio_actual - row["anio_matricula"] if pd.notna(row["anio_matricula"]) else None,
                "precio": row["precio"] if pd.notna(row["precio"]) else None,
                "mes_matricula": row["mes_matricula"] if pd.notna(row["mes_matricula"]) else None,
                "anio_matricula": row["anio_matricula"] if pd.notna(row["anio_matricula"]) else None,
                "concesionario_id": concesionario_id,
                "url_id": url_id,
                "ruta_imagen_id": ruta_imagen_id
            }

            #data = {k: v for k, v in data.items() if v is not None}
            
            print ("Antes del query")
            
            query = f"""
            INSERT IGNORE INTO coches_en_venta ({', '.join(data.keys())})
            VALUES ({', '.join(['%s' for _ in data.keys()])})
            """
            print(query)

            cursor = self.connection.cursor(buffered=True)
            cursor.execute(query, tuple(data.values()))
            self.connection.commit()
            cursor.close()


if __name__ == "__main__":
    loader = MySQLDataLoader("grupocds", "JoSanBross", "pfb_coches")
    loader.process_csv_concesionarios("/home/bross/Codigo_HAB/PFB_coches/PFB_coches/data/concesionarios_limpio.csv")
    loader.process_csv_coches("/home/bross/Codigo_HAB/PFB_coches/PFB_coches/data/coches_segunda_mano-19-02-2025_limpio.csv")
# Out:
# --AUTOMOVILES VIA NORTE --
# La coruña
# Naron
# tabla provincia, columna nombre_provincia, valor La coruña
# tabla municipio, columna nombre_municipio, valor Naron
# *ACS MOTOR*
# Cuenca
# Iniesta
# tabla provincia, columna nombre_provincia, valor Cuenca
# tabla municipio, columna nombre_municipio, valor Iniesta
# + QUE COCHES
# Toledo
# Talavera de la reina
# tabla provincia, columna nombre_provincia, valor Toledo
# tabla municipio, columna nombre_municipio, valor Talavera de la reina
# 11ELEVEN
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# 13 Premium Cars
# Valencia
# Aldaia
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Aldaia
# 14 GARAGE
# Madrid
# Villalbilla
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Villalbilla
# 2015 GESTIO MOTORS
# Girona
# Cornella de terri
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Cornella de terri
# 24H Lemans
# Valencia
# Picassent
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Picassent
# 3 RL CARS
# Segovia
# Segovia
# tabla provincia, columna nombre_provincia, valor Segovia
# tabla municipio, columna nombre_municipio, valor Segovia
# 3D WORLD SPAIN
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# 4X4 LA AZUCARERA
# Málaga
# Malaga
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Malaga
# 500 MILLAS AUTOMOVILES
# Islas baleares
# Palma de mallorca
# tabla provincia, columna nombre_provincia, valor Islas baleares
# tabla municipio, columna nombre_municipio, valor Palma de mallorca
# 515 Auto-Grs
# Málaga
# Marbella
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Marbella
# 66 Garage
# Madrid
# Moraleja de enmedio
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Moraleja de enmedio
# 77 CARS
# Málaga
# Nueva andalucia ,
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Nueva andalucia ,
# 7CARS MOTION
# Málaga
# Velez
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Velez
# 81 MOTOR
# Valladolid
# Valladolid
# tabla provincia, columna nombre_provincia, valor Valladolid
# tabla municipio, columna nombre_municipio, valor Valladolid
# 90 AND ONE TEN
# Barcelona
# Rajadell
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Rajadell
# 911 MADRID
# Madrid
# La moraleja
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor La moraleja
# A G C
# Vizcaya
# Vizcaya
# tabla provincia, columna nombre_provincia, valor Vizcaya
# tabla municipio, columna nombre_municipio, valor Vizcaya
# A. J. Investment Logistics Control S.L.
# nan
# Don benito
# tabla municipio, columna nombre_municipio, valor Don benito
# A.ROMAN SANCHEZ S.L
# Ciudad real
# Alcazar de san juan
# tabla provincia, columna nombre_provincia, valor Ciudad real
# tabla municipio, columna nombre_municipio, valor Alcazar de san juan
# AB CARS LLEIDA
# Lleida
# Rosello
# tabla provincia, columna nombre_provincia, valor Lleida
# tabla municipio, columna nombre_municipio, valor Rosello
# AB Development SL
# nan
# Malaga
# tabla municipio, columna nombre_municipio, valor Malaga
# Ab Marbella Cars
# Málaga
# Marbella
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Marbella
# AB MOTOR
# Alicante
# El vergel
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor El vergel
# ABALO SPORT
# Pontevedra
# Catoira
# tabla provincia, columna nombre_provincia, valor Pontevedra
# tabla municipio, columna nombre_municipio, valor Catoira
# ABASTAUTO
# Barcelona
# Sant fruitós de bages
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Sant fruitós de bages
# ABATE AUTO Cars and Services
# Islas baleares
# Eivissa
# tabla provincia, columna nombre_provincia, valor Islas baleares
# tabla municipio, columna nombre_municipio, valor Eivissa
# ABEL AUTOMOVILES
# Asturias
# Castrillon
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Castrillon
# AC CAR
# Madrid
# Las rozas
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Las rozas
# AC CAR (Barcelona)
# Barcelona
# Mollet del valles
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Mollet del valles
# AC MACHINERY TRADING S.L.U.
# nan
# Almeria
# tabla municipio, columna nombre_municipio, valor Almeria
# AC MACHINERY TRADING SLU
# nan
# Nijar
# tabla municipio, columna nombre_municipio, valor Nijar
# AC PERFORMANCE
# Pontevedra
# Vilagarcia de arousa
# tabla provincia, columna nombre_provincia, valor Pontevedra
# tabla municipio, columna nombre_municipio, valor Vilagarcia de arousa
# ACAUTO
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# ACCIMOVIL
# Granada
# Guadix - granada
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Guadix - granada
# ACCIÓ VO
# Girona
# Vilamalla
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Vilamalla
# ACEROM ASESORES
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ACIERTOCARS
# Madrid
# Algete
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Algete
# ACOSTA SERVICES CAR SL
# nan
# Playa del ingles
# tabla municipio, columna nombre_municipio, valor Playa del ingles
# ACTIVACIONS CARRETILLAS, S.L
# Barcelona
# nan
# tabla provincia, columna nombre_provincia, valor Barcelona
# AD CARMARKET
# La rioja
# Arnedo
# tabla provincia, columna nombre_provincia, valor La rioja
# tabla municipio, columna nombre_municipio, valor Arnedo
# AD.I.M sl
# nan
# Almeria
# tabla municipio, columna nombre_municipio, valor Almeria
# ADAM CARS
# Murcia
# Nonduermas
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Nonduermas
# ADAM FOSTER
# Madrid
# Rozas de madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Rozas de madrid
# ADAPTA-MOVIL
# Murcia
# Molina de segura
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Molina de segura
# Adarsa Salamanca Mercedes Benz y Mitsubishi
# Salamanca
# Salamanca
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Salamanca
# ADEINNOVA CONSULTORES SL
# nan
# Artesa del segre
# tabla municipio, columna nombre_municipio, valor Artesa del segre
# Adit Car
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ADOLFO FERRERO
# nan
# Vicolozano
# tabla municipio, columna nombre_municipio, valor Vicolozano
# ADVENTURE CENTER
# Madrid
# Móstoles
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Móstoles
# ADVENTURE CENTER VN.
# Madrid
# Mostoles
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Mostoles
# Aelia Motor
# Barcelona
# Ripollet
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Ripollet
# AERO AUTOFACTORIA SPAIN
# Girona
# Salt
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Salt
# AF VANS
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# AF VANS
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# AFRON, S.A.
# Madrid
# nan
# tabla provincia, columna nombre_provincia, valor Madrid
# AG Buycars
# Granada
# Padul
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Padul
# AG CarDrive
# Barcelona
# Vilanova i la geltrú
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Vilanova i la geltrú
# AGNANO INVERSIONES
# Tarragona
# nan
# tabla provincia, columna nombre_provincia, valor Tarragona
# AGRA MARTIN 2016
# Madrid
# Collado villalba
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Collado villalba
# AGRÃCOLA CUELLAR, S.A.
# Segovia
# nan
# tabla provincia, columna nombre_provincia, valor Segovia
# AGRÃCOLA GARVIN, S.L.
# Toledo
# nan
# tabla provincia, columna nombre_provincia, valor Toledo
# Agricola Vilanova SL
# nan
# Oroso
# tabla municipio, columna nombre_municipio, valor Oroso
# AGRINSUR, S.A.
# Sevilla
# nan
# tabla provincia, columna nombre_provincia, valor Sevilla
# AGRISA
# La rioja
# Logroño
# tabla provincia, columna nombre_provincia, valor La rioja
# tabla municipio, columna nombre_municipio, valor Logroño
# AGRITRASA AUTOAGRICOLA
# Toledo
# nan
# tabla provincia, columna nombre_provincia, valor Toledo
# AGRITRASA MOTOR
# Ciudad real
# Ciudad real
# tabla provincia, columna nombre_provincia, valor Ciudad real
# tabla municipio, columna nombre_municipio, valor Ciudad real
# AGROCAR
# nan
# Ponferrada (leon)
# tabla municipio, columna nombre_municipio, valor Ponferrada (leon)
# AGROMECANICA CARIÑENA, S.L.
# Zaragoza
# nan
# tabla provincia, columna nombre_provincia, valor Zaragoza
# AGROMOTOR OCASION
# Álava
# Vitoria
# tabla provincia, columna nombre_provincia, valor Álava
# tabla municipio, columna nombre_municipio, valor Vitoria
# AGROMOTOR Peugeot Vitoria
# Álava
# Vitoria
# tabla provincia, columna nombre_provincia, valor Álava
# tabla municipio, columna nombre_municipio, valor Vitoria
# AGRONIMER, S.L.U.
# Murcia
# nan
# tabla provincia, columna nombre_provincia, valor Murcia
# Agropecuaria Molet
# nan
# Altorricón
# tabla municipio, columna nombre_municipio, valor Altorricón
# Aguas subterraneas
# nan
# Ondara
# tabla municipio, columna nombre_municipio, valor Ondara
# Aguassubterraneas
# nan
# Ondara
# tabla municipio, columna nombre_municipio, valor Ondara
# AGÜERAUTO MOTOR
# Málaga
# Coin
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Coin
# AGUILERA AUTOCENTROS
# Madrid
# San sebastian de los reyes
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor San sebastian de los reyes
# AINA MOTORS
# Guadalajara
# Pozo de guadalajara
# tabla provincia, columna nombre_provincia, valor Guadalajara
# tabla municipio, columna nombre_municipio, valor Pozo de guadalajara
# AIR COOLED MOTOR
# Madrid
# San agustin del guadalix
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor San agustin del guadalix
# AJ Automotive
# Sevilla
# Utrera
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor Utrera
# AJ AUTOMÓVILES
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# AJ MOTORS
# Barcelona
# Cerdanyola del valles
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Cerdanyola del valles
# Aj Racing Cars
# Madrid
# Valdemoro
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Valdemoro
# AKAAUTO
# Madrid
# Mostoles
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Mostoles
# ALAIN
# Alicante
# Torrevieja
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Torrevieja
# ALBA OCASIÓN
# Sevilla
# Gelves
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor Gelves
# ALBERTO POZUELO
# Madrid
# Pozuelo de alarcon
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Pozuelo de alarcon
# ALBO EXPORT
# Valladolid
# Aldeamayor de san martín
# tabla provincia, columna nombre_provincia, valor Valladolid
# tabla municipio, columna nombre_municipio, valor Aldeamayor de san martín
# ALBORAN MOTOR
# Almería
# Huercal
# tabla provincia, columna nombre_provincia, valor Almería
# tabla municipio, columna nombre_municipio, valor Huercal
# ALCALA 534 CTRA VALENCIA VN
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ALCOMA INTERNACIONAL 1984 - GRANADA
# nan
# Granada
# tabla municipio, columna nombre_municipio, valor Granada
# ALCOMOCION
# Alicante
# Elche
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Elche
# ALD ARGANDA DURSAN
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ALD BURGOS DURSAN
# Burgos
# Villagonzalo
# tabla provincia, columna nombre_provincia, valor Burgos
# tabla municipio, columna nombre_municipio, valor Villagonzalo
# ALD DURSAN SALAMANCA
# Salamanca
# Salamanca
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Salamanca
# ALD LEON DURSAN
# León
# Leon
# tabla provincia, columna nombre_provincia, valor León
# tabla municipio, columna nombre_municipio, valor Leon
# ALD VALLADOLID DURSAN
# Valladolid
# Zaratan
# tabla provincia, columna nombre_provincia, valor Valladolid
# tabla municipio, columna nombre_municipio, valor Zaratan
# ALDEA QUERCUS,S.L
# nan
# Estepona
# tabla municipio, columna nombre_municipio, valor Estepona
# ALEA AUTOMOCION
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ALEMARCOCHES
# Alicante
# Ondara
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Ondara
# ALENA`S CARS
# Sevilla
# Utrera
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor Utrera
# ALENMOCAR
# Madrid
# Mejorada del campo
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Mejorada del campo
# ALEX TAX
# Valencia
# Valencia
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Valencia
# ALEZEN, S.L.
# Salamanca
# Narrillos de san leonardo
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Narrillos de san leonardo
# ALF MOTOR
# Murcia
# Cartagena
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Cartagena
# ALFAGEME AUTOMOVILES S.L
# Valladolid
# Valladolid
# tabla provincia, columna nombre_provincia, valor Valladolid
# tabla municipio, columna nombre_municipio, valor Valladolid
# Alfredo Rueda
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ALGAMAUTO
# Madrid
# Mejorada del campo
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Mejorada del campo
# ALHAMBRA AUTOMOVILES, S.A.
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# Alixares Motor
# Granada
# Zubia
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Zubia
# Aljune
# Murcia
# Las torres de cotillas
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Las torres de cotillas
# ALKIMAKI
# nan
# Fuente el saz del jarama
# tabla municipio, columna nombre_municipio, valor Fuente el saz del jarama
# ALKIZABAL SL
# nan
# Lemoa
# tabla municipio, columna nombre_municipio, valor Lemoa
# ALL ELECTRIK
# Madrid
# Meco
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Meco
# ALLTRUCKSES
# Lleida
# nan
# tabla provincia, columna nombre_provincia, valor Lleida
# ALMACAR MOTOR
# Albacete
# Almansa
# tabla provincia, columna nombre_provincia, valor Albacete
# tabla municipio, columna nombre_municipio, valor Almansa
# Almirante Motor
# Granada
# Baza
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Baza
# ALMOTOR 26
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ALO WAGEN
# Castellón
# Vila-real
# tabla provincia, columna nombre_provincia, valor Castellón
# tabla municipio, columna nombre_municipio, valor Vila-real
# ALONSO AUTOMOCION
# Lugo
# Lugo
# tabla provincia, columna nombre_provincia, valor Lugo
# tabla municipio, columna nombre_municipio, valor Lugo
# ALONSO HERMANOS AUTOMOVILES
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ALONSO PINEDA
# Toledo
# Olías del rey
# tabla provincia, columna nombre_provincia, valor Toledo
# tabla municipio, columna nombre_municipio, valor Olías del rey
# Alpik Automobile
# Madrid
# Arganda del rey
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Arganda del rey
# ALPIMAC MAQUINARIA S.L.
# nan
# A coruña
# tabla municipio, columna nombre_municipio, valor A coruña
# ALQUICOCHE
# Valencia
# Valencia
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Valencia
# ALQUIFRE
# Cádiz
# nan
# tabla provincia, columna nombre_provincia, valor Cádiz
# ALQUIGAL
# nan
# Arteixo
# tabla municipio, columna nombre_municipio, valor Arteixo
# ALQUIGEMASUR
# nan
# Utrera sevilla
# tabla municipio, columna nombre_municipio, valor Utrera sevilla
# ALQUILER DE MAQUINARIA RENTAIRE, S.A.
# Madrid
# nan
# tabla provincia, columna nombre_provincia, valor Madrid
# Alquiler de Maquinaria Vega Baja
# nan
# Almoradi
# tabla municipio, columna nombre_municipio, valor Almoradi
# Alquiler de Maquinarias
# Lugo
# Lugo
# tabla provincia, columna nombre_provincia, valor Lugo
# tabla municipio, columna nombre_municipio, valor Lugo
# Alquileres Garbayo S.L.
# Navarra
# Tudela
# tabla provincia, columna nombre_provincia, valor Navarra
# tabla municipio, columna nombre_municipio, valor Tudela
# ALQUIMECANICA, S.L.
# Madrid
# nan
# tabla provincia, columna nombre_provincia, valor Madrid
# Alquiven de maquinaria 2000 sl
# nan
# Castellon
# tabla municipio, columna nombre_municipio, valor Castellon
# ALQUIVEN MAQUINARIA 2000, S.L
# Castellón
# nan
# tabla provincia, columna nombre_provincia, valor Castellón
# ALR
# Barcelona
# Vic
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Vic
# ALR LUXURY TIME, SL
# Barcelona
# Matadepera
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Matadepera
# ALSAGIL
# Castellón
# nan
# tabla provincia, columna nombre_provincia, valor Castellón
# ALSAM VENTA MAQUINARIA S.L.
# nan
# Martorelles
# tabla municipio, columna nombre_municipio, valor Martorelles
# Alsecan Auto
# Cantabria
# Cartes
# tabla provincia, columna nombre_provincia, valor Cantabria
# tabla municipio, columna nombre_municipio, valor Cartes
# ALTRASAN, S.L.
# Pontevedra
# nan
# tabla provincia, columna nombre_provincia, valor Pontevedra
# ALTUNA PEÑIN REMARKETING, S. L
# nan
# Algete
# tabla municipio, columna nombre_municipio, valor Algete
# Alv Alba Irauto
# Zamora
# Benavente
# tabla provincia, columna nombre_provincia, valor Zamora
# tabla municipio, columna nombre_municipio, valor Benavente
# ÁLVARO Álfaro
# Girona
# Figueres
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Figueres
# ALVARO NAVARRO
# Alicante
# Elche
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Elche
# ALVARO PÉREZ
# Burgos
# Revillarruz
# tabla provincia, columna nombre_provincia, valor Burgos
# tabla municipio, columna nombre_municipio, valor Revillarruz
# ALVE FORKLIFT
# Sevilla
# El puntual
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor El puntual
# Alvegirona 2000 SL
# Girona
# Fornells de la selva
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Fornells de la selva
# ALYHU MOTOR
# Salamanca
# Salamanca
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Salamanca
# ALZ-MOTORS
# Navarra
# Noain
# tabla provincia, columna nombre_provincia, valor Navarra
# tabla municipio, columna nombre_municipio, valor Noain
# AM AUTOMOVILES MONTERO
# Albacete
# Albacete
# tabla provincia, columna nombre_provincia, valor Albacete
# tabla municipio, columna nombre_municipio, valor Albacete
# AM AUTOS
# Alicante
# Torrevieja
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Torrevieja
# AM CARS
# Málaga
# Málaga
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Málaga
# Amadeo Garcia
# nan
# Baza
# tabla municipio, columna nombre_municipio, valor Baza
# AMAQ
# nan
# Zamora
# tabla municipio, columna nombre_municipio, valor Zamora
# AMARO CEREZO
# Valladolid
# Valladolid
# tabla provincia, columna nombre_provincia, valor Valladolid
# tabla municipio, columna nombre_municipio, valor Valladolid
# AMCO Machinery & Consulting
# nan
# Gijon
# tabla municipio, columna nombre_municipio, valor Gijon
# AMCO MACHINERY & CONSULTING
# nan
# Gijon (asturias)
# tabla municipio, columna nombre_municipio, valor Gijon (asturias)
# AMENCARS
# Madrid
# Alcobendas
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Alcobendas
# AMERICAN MADE CARS
# Madrid
# Rivas-vaciamadrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Rivas-vaciamadrid
# AMG AUTOBENALUP
# Cádiz
# Benalup-casas viejas
# tabla provincia, columna nombre_provincia, valor Cádiz
# tabla municipio, columna nombre_municipio, valor Benalup-casas viejas
# Ammar Machinery Concept S.L.U
# nan
# Benidorm
# tabla municipio, columna nombre_municipio, valor Benidorm
# AMOTOR
# Girona
# Vilablareix
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Vilablareix
# Ana Maria Pastor Hernandez
# nan
# Torrevieja
# tabla municipio, columna nombre_municipio, valor Torrevieja
# ANDALGROUP COCHES SIN CARNET
# Sevilla
# Sevilla
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor Sevilla
# ANDIKO AUTOAK
# Vizcaya
# Vizcaya
# tabla provincia, columna nombre_provincia, valor Vizcaya
# tabla municipio, columna nombre_municipio, valor Vizcaya
# ANDRADA CARS
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# ANDRADA OCASION
# Alicante
# Jávea
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Jávea
# Andrema Motor
# Murcia
# Lorca
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Lorca
# ANDRÉS GONZÁLEZ SANZ EXCAVACIONES S. L.
# nan
# Cerceda
# tabla municipio, columna nombre_municipio, valor Cerceda
# ANDRONEBULA SL
# Tarragona
# Tarragona
# tabla provincia, columna nombre_provincia, valor Tarragona
# tabla municipio, columna nombre_municipio, valor Tarragona
# ANGALTRUCK
# Málaga
# Malaga
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Malaga
# Angel Vehículos Seminuevos
# Ciudad real
# Alcazar de san juan
# tabla provincia, columna nombre_provincia, valor Ciudad real
# tabla municipio, columna nombre_municipio, valor Alcazar de san juan
# Anicovem S.L.
# nan
# Alcala de guadaira
# tabla municipio, columna nombre_municipio, valor Alcala de guadaira
# ANLOBER
# Barcelona
# nan
# tabla provincia, columna nombre_provincia, valor Barcelona
# ANNA FONT FABREGÓ
# nan
# Manlleu
# tabla municipio, columna nombre_municipio, valor Manlleu
# Anper Ocasion
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# Anrour
# León
# Leon
# tabla provincia, columna nombre_provincia, valor León
# tabla municipio, columna nombre_municipio, valor Leon
# ANTONAUTO
# Madrid
# Alcobendas
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Alcobendas
# ANTONIO BRAVO
# Badajoz
# Badajoz
# tabla provincia, columna nombre_provincia, valor Badajoz
# tabla municipio, columna nombre_municipio, valor Badajoz
# ANTONIO DOMINGUEZ, S.L.
# Cádiz
# nan
# tabla provincia, columna nombre_provincia, valor Cádiz
# ANTONIO FEITO S.A.
# nan
# Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# Antonio Ocasion
# Málaga
# Malaga
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Malaga
# ANTONIO TORRES MARTIN
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ANZEVE S.L.
# nan
# Leganés
# tabla municipio, columna nombre_municipio, valor Leganés
# APASIONAUTO
# Valencia
# Godelleta
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Godelleta
# APE PLATAFORMAS ELEVADORAS
# nan
# Hospitalet llobregat
# tabla municipio, columna nombre_municipio, valor Hospitalet llobregat
# APER DIAMOND, S.L.U.
# nan
# Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# APOU
# Barcelona
# Manlleu
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Manlleu
# Apoyo Dursan Madrid Torrejón
# Madrid
# Arganda del rey
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Arganda del rey
# APT CAR
# Barcelona
# Granollers
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Granollers
# AQUASONDA SL
# nan
# Torre del mar
# tabla municipio, columna nombre_municipio, valor Torre del mar
# AQUITUCOCHE
# Castellón
# Castellón de la plana
# tabla provincia, columna nombre_provincia, valor Castellón
# tabla municipio, columna nombre_municipio, valor Castellón de la plana
# AR MOTOR
# Orense
# Ourense
# tabla provincia, columna nombre_provincia, valor Orense
# tabla municipio, columna nombre_municipio, valor Ourense
# Aracars
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# Aragonesa de Recambios para Limpieza SL
# nan
# Cadrete
# tabla municipio, columna nombre_municipio, valor Cadrete
# ARAMÓVIL
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# ARAVI, S.L.
# Zaragoza
# nan
# tabla provincia, columna nombre_provincia, valor Zaragoza
# ARCI MOTOR
# Cádiz
# Arcos de la frontera
# tabla provincia, columna nombre_provincia, valor Cádiz
# tabla municipio, columna nombre_municipio, valor Arcos de la frontera
# ARCOMÓVIL, concesionario oficial Ford
# Murcia
# Murcia
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Murcia
# ÁREA AUTOEXPO
# Tarragona
# Tarragona
# tabla provincia, columna nombre_provincia, valor Tarragona
# tabla municipio, columna nombre_municipio, valor Tarragona
# AREA EL 9 COTXES
# Lleida
# Tora
# tabla provincia, columna nombre_provincia, valor Lleida
# tabla municipio, columna nombre_municipio, valor Tora
# AREIA VEHICULOS DE OCASION
# Madrid
# Pozuelo de alarcón
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Pozuelo de alarcón
# Arevalo Logistics
# Valencia
# Ribarroja
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Ribarroja
# ARGÜELLES CARS S.L
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# Aridos del Noroeste S.L
# La coruña
# La coruña
# tabla provincia, columna nombre_provincia, valor La coruña
# tabla municipio, columna nombre_municipio, valor La coruña
# Áridos Técnicos
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ARIES
# Toledo
# Olias del rey
# tabla provincia, columna nombre_provincia, valor Toledo
# tabla municipio, columna nombre_municipio, valor Olias del rey
# ARIES VN -STOCK
# Toledo
# Toledo
# tabla provincia, columna nombre_provincia, valor Toledo
# tabla municipio, columna nombre_municipio, valor Toledo
# ARLANZON MOTOR CUPRA
# Burgos
# Burgos
# tabla provincia, columna nombre_provincia, valor Burgos
# tabla municipio, columna nombre_municipio, valor Burgos
# ARLANZON MOTOR SEAT
# Burgos
# Burgos
# tabla provincia, columna nombre_provincia, valor Burgos
# tabla municipio, columna nombre_municipio, valor Burgos
# ARNABAT, S.A.
# Barcelona
# nan
# tabla provincia, columna nombre_provincia, valor Barcelona
# ARNAIZ TRANSPORTES Y EXCAVACIONES.
# nan
# Valladolid
# tabla municipio, columna nombre_municipio, valor Valladolid
# ARROBAMOTOR
# Barcelona
# Ripollet
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Ripollet
# ARTES MOTOR S.L.
# Barcelona
# Artés
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Artés
# AS AUTOMÓVILES.
# Madrid
# Las rozas
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Las rozas
# AS COMPRA & VENTA CARS
# Alicante
# Pilar de la horadada
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Pilar de la horadada
# ASAUTO HOUSE
# Asturias
# Piedrasblancas
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Piedrasblancas
# ASautos
# Málaga
# Malaga
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Malaga
# Ascendum Maquinaria
# Madrid
# nan
# tabla provincia, columna nombre_provincia, valor Madrid
# ASENCIO AUTOMOCION
# Cádiz
# Arcos de la frontera
# tabla provincia, columna nombre_provincia, valor Cádiz
# tabla municipio, columna nombre_municipio, valor Arcos de la frontera
# ASESCAR JAEN.
# Jaén
# Jaen
# tabla provincia, columna nombre_provincia, valor Jaén
# tabla municipio, columna nombre_municipio, valor Jaen
# ASHT ON POR T AL LIMITED
# Pontevedra
# Pontevedra
# tabla provincia, columna nombre_provincia, valor Pontevedra
# tabla municipio, columna nombre_municipio, valor Pontevedra
# Asphalt Cars
# Alicante
# Guardamar del segura,
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Guardamar del segura,
# ASTER AUTOS
# Lleida
# Lleida
# tabla provincia, columna nombre_provincia, valor Lleida
# tabla municipio, columna nombre_municipio, valor Lleida
# ASTIAUTO DONOSTI
# Guipúzcoa
# Zarautz
# tabla provincia, columna nombre_provincia, valor Guipúzcoa
# tabla municipio, columna nombre_municipio, valor Zarautz
# ASTON MARTIN TAYRE
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# ASTURBENZ
# Asturias
# Aviles
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Aviles
# ASTURJAVE
# Asturias
# Asturias
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Asturias
# ASV Motor
# Girona
# Palafrugell
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Palafrugell
# ASV MOTORSPORT
# Alicante
# Salinas
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Salinas
# ATHLON CAR LEASE SPAIN,S.A.
# Barcelona
# Santa perpetua de la mogoda
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Santa perpetua de la mogoda
# ATHLON CAR LEASE SPAIN.
# Madrid
# Algete
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Algete
# Atlantic machinery equipment Sl
# nan
# Cerdanyola del valles
# tabla municipio, columna nombre_municipio, valor Cerdanyola del valles
# ATLANTICENT
# Barcelona
# Castelldefels
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Castelldefels
# ATM AUTOMOCION
# Barcelona
# Cabrera de mar
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Cabrera de mar
# ATURSA AUTOMOCION, acuerdo Ford
# Valencia
# Valencia
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Valencia
# AUCALGA
# Asturias
# Siero
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Siero
# AUDI ALZAGA MOTOR
# Vizcaya
# Bilbao
# tabla provincia, columna nombre_provincia, valor Vizcaya
# tabla municipio, columna nombre_municipio, valor Bilbao
# AUDI ALZAGA MOTOR - VITORIA
# Álava
# Vitoria-gasteiz
# tabla provincia, columna nombre_provincia, valor Álava
# tabla municipio, columna nombre_municipio, valor Vitoria-gasteiz
# AUDI CENTER PALMA
# Islas baleares
# Palma de mallorca
# tabla provincia, columna nombre_provincia, valor Islas baleares
# tabla municipio, columna nombre_municipio, valor Palma de mallorca
# AUDI CENTER ZARAGOZA
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# AUDI HELMANTICA SALAMANCA
# Salamanca
# Villares de la reina
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Villares de la reina
# AUDI HELMANTICA VN
# Salamanca
# Villares de la reina
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Villares de la reina
# AUDI HUERTAS MOTOR CARTAGENA
# Murcia
# Cartagena
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Cartagena
# AUDI HUERTAS MOTOR MURCIA
# Murcia
# Murcia
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Murcia
# AUDI HUESCA IMPORT VN
# Huesca
# Huesca
# tabla provincia, columna nombre_provincia, valor Huesca
# tabla municipio, columna nombre_municipio, valor Huesca
# AUDI SEALCO MOTOR I
# Madrid
# Alcorcón
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Alcorcón
# AUDI SELECTION PLUS
# Girona
# Girona
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Girona
# AUDI VILAMÒBIL
# Tarragona
# Tarragona
# tabla provincia, columna nombre_provincia, valor Tarragona
# tabla municipio, columna nombre_municipio, valor Tarragona
# AUDILLISA
# Granada
# Peligros
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Peligros
# AUNORSA
# Murcia
# Lorca
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Lorca
# AUPASA OCASION PALENCIA
# Palencia
# Palencia
# tabla provincia, columna nombre_provincia, valor Palencia
# tabla municipio, columna nombre_municipio, valor Palencia
# AURA MOTOR, Concesionario Oficial TOYOTA
# Girona
# Les preses
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Les preses
# AURUM AUTOMOVILES
# Valencia
# Gandia
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Gandia
# AUTERSA CASTELLÓN
# Castellón
# Castellón
# tabla provincia, columna nombre_provincia, valor Castellón
# tabla municipio, columna nombre_municipio, valor Castellón
# AUTO 1 GESTION INTEGRAL, S.L.
# Madrid
# San martin de la vega
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor San martin de la vega
# AUTO 22
# Barcelona
# Montcada
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Montcada
# AUTO ALEX PERFORMANCE
# Pontevedra
# Vigo
# tabla provincia, columna nombre_provincia, valor Pontevedra
# tabla municipio, columna nombre_municipio, valor Vigo
# Auto Almendra
# Alicante
# Novelda
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Novelda
# AUTO BENAMAR
# Barcelona
# Santa coloma de gramenet
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Santa coloma de gramenet
# AUTO BOSS
# Sevilla
# Mairena del aljarafe
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor Mairena del aljarafe
# AUTO BOSS V.N.
# Sevilla
# Mairena del aljarafe
# tabla provincia, columna nombre_provincia, valor Sevilla
# tabla municipio, columna nombre_municipio, valor Mairena del aljarafe
# AUTO BRIBON
# Barcelona
# Cabrera del mar
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Cabrera del mar
# AUTO CAMBRILS
# Tarragona
# Tarragona
# tabla provincia, columna nombre_provincia, valor Tarragona
# tabla municipio, columna nombre_municipio, valor Tarragona
# AUTO CARS EXPORT
# Madrid
# Fuenlabrada
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Fuenlabrada
# AUTO CATALUNYA
# Tarragona
# Tortosa
# tabla provincia, columna nombre_provincia, valor Tarragona
# tabla municipio, columna nombre_municipio, valor Tortosa
# AUTO COLLECTION IBIZA ..
# Islas baleares
# Sant jordi
# tabla provincia, columna nombre_provincia, valor Islas baleares
# tabla municipio, columna nombre_municipio, valor Sant jordi
# AUTO CONSIGLIERE
# Badajoz
# Badajoz
# tabla provincia, columna nombre_provincia, valor Badajoz
# tabla municipio, columna nombre_municipio, valor Badajoz
# AUTO COSTA BRAVA
# Girona
# Rosas
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Rosas
# AUTO DIAGONAL
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# AUTO DINAMIC
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# AUTO DISEÑO 99
# Valencia
# Benetusser
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Benetusser
# AUTO DMD CARE
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# AUTO ELAND BARCELONA
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# AUTO ELAND MADRID
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# AUTO ELECTRICIDAD ARREGUI
# Álava
# Vitoria
# tabla provincia, columna nombre_provincia, valor Álava
# tabla municipio, columna nombre_municipio, valor Vitoria
# AUTO ELIA VN
# Madrid
# Madrid
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Madrid
# AUTO ELIA, Volvo (SEDE PRINCIPAL)
# Madrid
# Alcalá de henares
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Alcalá de henares
# AUTO ESPLUGUES
# Barcelona
# Esplugues de llobregat
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Esplugues de llobregat
# AUTO EXCLUSIVE
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# Auto Export Magerit
# Madrid
# Galapar
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Galapar
# AUTO FECARSA
# Murcia
# Murcia
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Murcia
# AUTO FERNANDEZ
# Barcelona
# Vilafranca del penedés
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Vilafranca del penedés
# AUTO GO OCASION
# Madrid
# Valdemoro
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Valdemoro
# AUTO GONSE
# Soria
# Soria
# tabla provincia, columna nombre_provincia, valor Soria
# tabla municipio, columna nombre_municipio, valor Soria
# AUTO GRUAS ORIENTE
# Asturias
# Llanes
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Llanes
# AUTO IN SPAIN
# Alicante
# San vicente del raspeig
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor San vicente del raspeig
# AUTO JACRE
# Valladolid
# Valladolid
# tabla provincia, columna nombre_provincia, valor Valladolid
# tabla municipio, columna nombre_municipio, valor Valladolid
# AUTO JUPITER, concesionario oficial Ford
# Murcia
# Lorca
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Lorca
# AUTO KARMA
# Málaga
# Benalmadena
# tabla provincia, columna nombre_provincia, valor Málaga
# tabla municipio, columna nombre_municipio, valor Benalmadena
# AUTO LLAMAS IMPORT
# Barcelona
# Sabadell
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Sabadell
# AUTO LLAVERIA
# Barcelona
# Argentona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Argentona
# AUTO MARTIN ALCAÑIZ
# Teruel
# Alcañiz
# tabla provincia, columna nombre_provincia, valor Teruel
# tabla municipio, columna nombre_municipio, valor Alcañiz
# AUTO MORER
# Girona
# Puigcerda
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Puigcerda
# AUTO MOTOR CIUDAD REAL
# Ciudad real
# Carrión de calatrava
# tabla provincia, columna nombre_provincia, valor Ciudad real
# tabla municipio, columna nombre_municipio, valor Carrión de calatrava
# AUTO MOTOR RUIZ 2014
# Salamanca
# Tamames
# tabla provincia, columna nombre_provincia, valor Salamanca
# tabla municipio, columna nombre_municipio, valor Tamames
# AUTO MÜLLER
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# AUTO OJA VN T
# La rioja
# Logroño
# tabla provincia, columna nombre_provincia, valor La rioja
# tabla municipio, columna nombre_municipio, valor Logroño
# AUTO OJA, S.A.
# La rioja
# Logroño
# tabla provincia, columna nombre_provincia, valor La rioja
# tabla municipio, columna nombre_municipio, valor Logroño
# AUTO OUTLET MURCIA
# Murcia
# Lorqui
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Lorqui
# AUTO PALAS
# Cantabria
# Santander
# tabla provincia, columna nombre_provincia, valor Cantabria
# tabla municipio, columna nombre_municipio, valor Santander
# Auto Prestigio 2022
# Alicante
# Torrevieja
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Torrevieja
# AUTO RAMOS
# Barcelona
# Terrassa
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Terrassa
# Auto Recambios 4x4
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# AUTO REPARACIO VOLTREGA
# Barcelona
# Sant hipolit de voltrega
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Sant hipolit de voltrega
# AUTO REPARACIONS JORDI
# Lleida
# Lleida
# tabla provincia, columna nombre_provincia, valor Lleida
# tabla municipio, columna nombre_municipio, valor Lleida
# AUTO ROMA 94
# Barcelona
# San cugat del valles
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor San cugat del valles
# AUTO SALON VILLANUEVA
# Alicante
# Alfaz del pi
# tabla provincia, columna nombre_provincia, valor Alicante
# tabla municipio, columna nombre_municipio, valor Alfaz del pi
# Auto Selec Totana
# Murcia
# Alhama de murcia, ,
# tabla provincia, columna nombre_provincia, valor Murcia
# tabla municipio, columna nombre_municipio, valor Alhama de murcia, ,
# AUTO SELECT EDITION
# Girona
# Palafrugell
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Palafrugell
# AUTO SPEED
# Barcelona
# Vilanova y la geltru
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Vilanova y la geltru
# AUTO SPORT MORALEJA
# Madrid
# Arroyomolinos
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Arroyomolinos
# AUTO SPRINT
# Madrid
# Pinto
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Pinto
# AUTO STAR
# Madrid
# Barajas
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Barajas
# AUTO STEFAN
# Madrid
# Alcalá de henares
# tabla provincia, columna nombre_provincia, valor Madrid
# tabla municipio, columna nombre_municipio, valor Alcalá de henares
# AUTO STORE 80
# Barcelona
# Sabadell
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Sabadell
# AUTO STORICA
# Barcelona
# Sant boi de llobregat
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Sant boi de llobregat
# AUTO SUCRO
# Valencia
# Cullera
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Cullera
# AUTO TALLER EMILI BOSCH
# Girona
# Santa cristina de aro
# tabla provincia, columna nombre_provincia, valor Girona
# tabla municipio, columna nombre_municipio, valor Santa cristina de aro
# AUTO TALLERES SERRANO
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# AUTO UNIVERSAL
# Barcelona
# Barcelona
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Barcelona
# AUTO VALPORT
# Valencia
# Valencia
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Valencia
# AUTO WORK
# Tarragona
# Amposta
# tabla provincia, columna nombre_provincia, valor Tarragona
# tabla municipio, columna nombre_municipio, valor Amposta
# AUTO YALDE
# La rioja
# Logroño
# tabla provincia, columna nombre_provincia, valor La rioja
# tabla municipio, columna nombre_municipio, valor Logroño
# AUTO YALDE VN
# La rioja
# Logroño
# tabla provincia, columna nombre_provincia, valor La rioja
# tabla municipio, columna nombre_municipio, valor Logroño
# AUTO YEAR
# Zaragoza
# Zaragoza
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Zaragoza
# Auto-B
# Granada
# Puebla de don fadrique
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Puebla de don fadrique
# Auto-Cadrete AUTO BARAT
# Zaragoza
# Cadrete
# tabla provincia, columna nombre_provincia, valor Zaragoza
# tabla municipio, columna nombre_municipio, valor Cadrete
# AUTO-PRIETO
# Valencia
# Manises
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Manises
# AUTOALBA
# Albacete
# Albacete
# tabla provincia, columna nombre_provincia, valor Albacete
# tabla municipio, columna nombre_municipio, valor Albacete
# AUTOASTUR
# Asturias
# Corvera de asturias
# tabla provincia, columna nombre_provincia, valor Asturias
# tabla municipio, columna nombre_municipio, valor Corvera de asturias
# AUTOBAEZ HERMANOS
# Granada
# Santa fe
# tabla provincia, columna nombre_provincia, valor Granada
# tabla municipio, columna nombre_municipio, valor Santa fe
# AUTOBAGES, concesionario oficial Ford
# Barcelona
# Manresa
# tabla provincia, columna nombre_provincia, valor Barcelona
# tabla municipio, columna nombre_municipio, valor Manresa
# Autoblazquez
# Valencia
# Xativa
# tabla provincia, columna nombre_provincia, valor Valencia
# tabla municipio, columna nombre_municipio, valor Xativa
# AUTOBOX LOW COST
# Granada
# Peligros
# tabla provincia, columna nombre_provincia, valor Granada
# ...
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor NISSAN
# 27
# X-Trail 1.6 dCi Tekna 4x2 XTronic
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor Todo Terreno
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor C
# url
# ../img/coches/15453710-0-11190270467b605220beac0.93965702.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Híbrido
# tabla combustible, columna nombre_combustible, valor Híbrido
# antes de marca_Id
# tabla marca, columna nombre_marca, valor PEUGEOT
# 1
# 308 5P GT Pack Hybrid 225 eEAT8
# color
# tabla color, columna nombre_color, valor OTROS
# carroceria
# tabla carroceria, columna nombre_carroceria, valor Pequeño
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor ECO
# url
# ../img/coches/15453734-0-166933406467b605214703c4.06923283.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Híbrido
# tabla combustible, columna nombre_combustible, valor Híbrido
# antes de marca_Id
# tabla marca, columna nombre_marca, valor RENAULT
# 11
# Captur techno ETech full hybr.105 kW145CV
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor ECO
# url
# ../img/coches/15453753-0-280228884167b60521cddd43.98836028.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Híbrido
# tabla combustible, columna nombre_combustible, valor Híbrido
# antes de marca_Id
# tabla marca, columna nombre_marca, valor RENAULT
# 11
# Austral Evolution Mild Hybrid 103kW 140CV
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor ECO
# url
# ../img/coches/15453752-0-277945000767b60520ed4476.84152816.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor NISSAN
# 27
# Qashqai dCi 85 kW 115 CV E6D DCT NCONNECTA
# color
# tabla color, columna nombre_color, valor GRIS
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor nan
# url
# ../img/coches/15453709-0-338171920467b6052013b124.04729731.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Híbrido
# tabla combustible, columna nombre_combustible, valor Híbrido
# antes de marca_Id
# tabla marca, columna nombre_marca, valor PEUGEOT
# 1
# 3008 Hybrid 300 eEAT8 GT Pack
# color
# tabla color, columna nombre_color, valor ROJO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor ECO
# url
# ../img/coches/15453733-0-322695864167b6051fefe905.89840176.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Híbrido
# tabla combustible, columna nombre_combustible, valor Híbrido
# antes de marca_Id
# tabla marca, columna nombre_marca, valor PORSCHE
# 19
# Cayenne EHybrid
# color
# tabla color, columna nombre_color, valor NEGRO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor ECO
# url
# ../img/coches/15453751-0-233384015367b6051fd19911.83254005.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor NISSAN
# 27
# Qashqai dCi 85 kW 115 CV E6D ACENTA
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor nan
# url
# ../img/coches/15453708-0-59078069367b6051e3dfeb2.82245080.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Gasolina
# tabla combustible, columna nombre_combustible, valor Gasolina
# antes de marca_Id
# tabla marca, columna nombre_marca, valor PEUGEOT
# 1
# 3008 1.2 S&S PureTech Allure EAT6 130
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor C
# url
# ../img/coches/15453732-0-227250836167b6051eecb275.22947603.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor PORSCHE
# 19
# Cayenne 3.0 TD Tiptronic
# color
# tabla color, columna nombre_color, valor GRIS
# carroceria
# tabla carroceria, columna nombre_carroceria, valor 4x4, SUV o pickup
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor nan
# url
# ../img/coches/15453750-0-42989985267b6051e908956.62829900.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor TOYOTA
# 17
# Land Cruiser D-4D GX
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor Todo Terreno
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor C
# url
# ../img/coches/839e5e261ba4f2a5cd3e76b3775cd1cd16c75b56.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Gasolina
# tabla combustible, columna nombre_combustible, valor Gasolina
# antes de marca_Id
# tabla marca, columna nombre_marca, valor PEUGEOT
# 1
# Rifter 1.2 PureTech S&S Standard Allure 110
# color
# tabla color, columna nombre_color, valor GRIS
# carroceria
# tabla carroceria, columna nombre_carroceria, valor Monovolumen
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor C
# url
# ../img/coches/15453749-0-184264818067b6051d458342.94596363.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor RENAULT
# 11
# Mégane Business Blue dCi 85 kW 115CV SS
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor Pequeño
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor nan
# url
# ../img/coches/15453767-0-90747336067b6052eee8e04.28897988.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Diésel
# tabla combustible, columna nombre_combustible, valor Diésel
# antes de marca_Id
# tabla marca, columna nombre_marca, valor RENAULT
# 11
# Mégane Business Blue dCi 85 kW 115CV SS
# color
# tabla color, columna nombre_color, valor BLANCO
# carroceria
# tabla carroceria, columna nombre_carroceria, valor Pequeño
# distintivo
# tabla distintivo_ambiental, columna nombre_distintivo, valor nan
# url
# ../img/coches/15453766-0-38603662267b6052e38aa40.46213052.jpeg
# concesionario
# dentro del if
# Antes del data
# Antes del query
#
#             INSERT IGNORE INTO coches_en_venta (referencia, peninsula_baleares, combustible_id, potencia, cambio_automatico, carroceria_id, kilometraje, distintivo_ambiental_id, color_id, garantia, vendedor_profesional, plazas, puertas, certificado, fecha_extraccion, consumo, modelo_id, antiguedad, precio, mes_matricula, anio_matricula, concesionario_id, url_id, ruta_imagen_id)
#             VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
#
# Eléctrico
# tabla combustible, columna nombre_combustible, valor Eléctrico
# antes de marca_Id
# tabla marca, columna nombre_marca, valor TESLA
# None
# Model S 90D 4WD
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 211
#     209 loader = MySQLDataLoader("grupocds", "JoSanBross", "pfb_coches")
#     210 loader.process_csv_concesionarios("/home/bross/Codigo_HAB/PFB_coches/PFB_coches/data/concesionarios_limpio.csv")
# --> 211 loader.process_csv_coches("/home/bross/Codigo_HAB/PFB_coches/PFB_coches/data/coches_segunda_mano-19-02-2025_limpio.csv")
#
# Cell In[3], line 142, in MySQLDataLoader.process_csv_coches(self, file_path)
#     140 print(marca_id)
#     141 print(row["modelo_titulo"])
# --> 142 modelo_id = self.insert_modelo_titulo(marca_id, row["modelo_titulo"])
#     143 print("color")
#     144 color_id = self.insert_ignore("color", "nombre_color", row["color"])
#
# Cell In[3], line 57, in MySQLDataLoader.insert_modelo_titulo(self, marca_id, nombre_modelo)
#      55 result = cursor.fetchone()
#      56 cursor.close()
# ---> 57 return result[0]
#
# TypeError: 'NoneType' object is not subscriptable
